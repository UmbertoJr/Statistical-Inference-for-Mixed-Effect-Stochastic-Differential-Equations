# %%
from SAEM import Stochasti_Approximation_Expectation_Maximization
from time import time
import matplotlib.pyplot as plt

# %%
start = time()
# self.PARMIN = [0.01, 1e-6, 0.0001, 1e-5, 0.0001, 1e-5] ; self.PARMAX = [1, 1e-1, 0.05, 1e-1, 1, 1e-3]
#theta = [0.3, 0.009, 0.2, 0.3, 0.3, 0.0001]   # [0.27, 0.0005, 0.04, 0.0035, 0.18, 0.0001]
theta = [0.089, 0.0034, 0.2 , 0.2, 0.1, 5e-5] 
SAEM = Stochasti_Approximation_Expectation_Maximization()
#SAEM.inizializza(theta)
SAEM.run(theta)
print("tempo esecuzione : %.5f "% (time()-start))
# Out:
# ### ottimizazione iterazione :  0
# 	acceptance rate = 0.2967  for subject 1
# 	phi scelti: (9.590e-02 , 2.944e-03)  marginal y 5.1391e+77
# 	acceptance rate = 0.3267  for subject 2
# 	phi scelti: (1.135e-01 , 2.307e-03)  marginal y 1.5550e+67
# 	acceptance rate = 0.4800  for subject 3
# 	phi scelti: (1.448e-01 , 3.901e-04)  marginal y 6.8976e+83
# 	acceptance rate = 0.3567  for subject 4
# 	phi scelti: (1.271e-01 , 1.019e-03)  marginal y 2.1228e+62
# 	acceptance rate = 0.2700  for subject 5
# 	phi scelti: (1.062e-01 , 2.488e-03)  marginal y 7.2439e+91
# 	acceptance rate = 0.4067  for subject 6
# 	phi scelti: (1.376e-01 , 7.205e-04)  marginal y 1.3580e+63
#  final_simplex: (array([[1.15037140e-01, 1.68295305e-03, 2.00864059e-02, 9.72974223e-04,
#         2.45569133e-01, 4.48972001e-05],
#        [1.14987040e-01, 1.68412915e-03, 2.01073184e-02, 9.73964555e-04,
#         2.45501021e-01, 4.49047598e-05],
#        [1.15042384e-01, 1.68271354e-03, 2.00860790e-02, 9.73938284e-04,
#         2.45504984e-01, 4.49212446e-05],
#        [1.15040954e-01, 1.68391673e-03, 2.00844919e-02, 9.72312058e-04,
#         2.45513462e-01, 4.49173987e-05],
#        [1.15003226e-01, 1.68250329e-03, 2.01311250e-02, 9.72316268e-04,
#         2.45471612e-01, 4.49167231e-05],
#        [1.14980745e-01, 1.68182665e-03, 2.01293933e-02, 9.73974771e-04,
#         2.45518980e-01, 4.48951295e-05],
#        [1.14974849e-01, 1.67862885e-03, 2.00636882e-02, 9.72835462e-04,
#         2.45521171e-01, 4.49050536e-05]]), array([-1613.39966863, -1613.39966711, -1613.39966602, -1613.39966537,
#        -1613.39965026, -1613.39964848, -1613.39962937]))
#            fun: -1613.399668625614
#        message: 'Optimization terminated successfully.'
#           nfev: 745
#            nit: 471
#         status: 0
#        success: True
#              x: array([1.15037140e-01, 1.68295305e-03, 2.00864059e-02, 9.72974223e-04,
#        2.45569133e-01, 4.48972001e-05])
# ### ottimizazione iterazione :  1
# 	acceptance rate = 0.2867  for subject 1
# 	phi scelti: (1.081e-01 , 1.904e-03)  marginal y 3.1210e+76
# 	acceptance rate = 0.3133  for subject 2
# 	phi scelti: (1.200e-01 , 1.542e-03)  marginal y 1.3624e+66
# 	acceptance rate = 0.4567  for subject 3
# 	phi scelti: (1.471e-01 , 3.902e-04)  marginal y 1.1049e+83
# 	acceptance rate = 0.3067  for subject 4
# 	phi scelti: (1.256e-01 , 9.303e-04)  marginal y 1.1995e+61
# 	acceptance rate = 0.1600  for subject 5
# 	phi scelti: (1.228e-01 , 1.692e-03)  marginal y 1.1948e+89
# 	acceptance rate = 0.4500  for subject 6
# 	phi scelti: (1.347e-01 , 6.397e-04)  marginal y 4.2784e+62
#  final_simplex: (array([[1.27681810e-01, 1.17090349e-03, 1.86002586e-02, 7.97387166e-04,
#         2.99999991e-01, 4.99999879e-05],
#        [1.27668397e-01, 1.16944268e-03, 1.86021478e-02, 7.97325775e-04,
#         2.99999984e-01, 4.99999839e-05],
#        [1.27634911e-01, 1.17058126e-03, 1.86039936e-02, 7.97475066e-04,
#         2.99999988e-01, 4.99999593e-05],
#        [1.27635632e-01, 1.17142571e-03, 1.86034721e-02, 7.97527095e-04,
#         2.99999992e-01, 4.99999558e-05],
#        [1.27643863e-01, 1.17041080e-03, 1.86035768e-02, 7.97444929e-04,
#         2.99999991e-01, 4.99999338e-05],
#        [1.27656451e-01, 1.17011150e-03, 1.86027845e-02, 7.97396794e-04,
#         2.99999970e-01, 4.99999538e-05],
#        [1.27650346e-01, 1.17044506e-03, 1.86030423e-02, 7.97431951e-04,
#         2.99999965e-01, 4.99999533e-05]]), array([-1363.53281593, -1363.53281524, -1363.53278016, -1363.53276211,
#        -1363.53274531, -1363.53274325, -1363.53273134]))
#            fun: -1363.5328159340431
#        message: 'Optimization terminated successfully.'
#           nfev: 513
#            nit: 305
#         status: 0
#        success: True
#              x: array([1.27681810e-01, 1.17090349e-03, 1.86002586e-02, 7.97387166e-04,
#        2.99999991e-01, 4.99999879e-05])
# ### ottimizazione iterazione :  2
# 	acceptance rate = 0.2400  for subject 1
# 	phi scelti: (1.329e-01 , 8.151e-04)  marginal y 8.4376e+74
# 	acceptance rate = 0.3000  for subject 2
# 	phi scelti: (1.459e-01 , 8.366e-04)  marginal y 2.4599e+65
# 	acceptance rate = 0.4667  for subject 3
# 	phi scelti: (1.282e-01 , 4.403e-04)  marginal y 1.0605e+82
# 	acceptance rate = 0.2667  for subject 4
# 	phi scelti: (1.541e-01 , 5.904e-04)  marginal y 8.0734e+59
# 	acceptance rate = 0.1167  for subject 5
# 	phi scelti: (1.249e-01 , 1.016e-03)  marginal y 1.8846e+88
# 	acceptance rate = 0.3467  for subject 6
# 	phi scelti: (1.482e-01 , 4.699e-04)  marginal y 4.8113e+61
#  final_simplex: (array([[1.34065877e-01, 1.17090349e-03, 1.86002586e-02, 7.97387166e-04,
#         2.99999991e-01, 4.99999974e-05],
#        [1.34065901e-01, 1.17090349e-03, 1.86002586e-02, 7.97387166e-04,
#         2.99999991e-01, 4.99999879e-05],
#        [1.34065877e-01, 1.17090349e-03, 1.86002586e-02, 7.97387166e-04,
#         2.99999991e-01, 4.99999879e-05],
#        [1.34065877e-01, 1.17090349e-03, 1.86002586e-02, 7.97387318e-04,
#         2.99999991e-01, 4.99999879e-05],
#        [1.34065877e-01, 1.17090349e-03, 1.86002622e-02, 7.97387166e-04,
#         2.99999991e-01, 4.99999879e-05],
#        [1.34065877e-01, 1.17090371e-03, 1.86002586e-02, 7.97387166e-04,
#         2.99999991e-01, 4.99999879e-05],
#        [1.34065882e-01, 1.17090353e-03, 1.86002594e-02, 7.97387198e-04,
#         2.99999977e-01, 4.99999899e-05]]), array([-1031.04569672, -1031.0456934 , -1031.04569131, -1031.04569066,
#        -1031.04569064, -1031.04569031, -1031.04564226]))
#            fun: -1031.0456967192342
#        message: 'Optimization terminated successfully.'
#           nfev: 155
#            nit: 21
#         status: 0
#        success: True
#              x: array([1.34065877e-01, 1.17090349e-03, 1.86002586e-02, 7.97387166e-04,
#        2.99999991e-01, 4.99999974e-05])
# ### ottimizazione iterazione :  3
# 	acceptance rate = 0.2367  for subject 1
# 	phi scelti: (1.329e-01 , 8.151e-04)  marginal y 3.0212e+75
# 	acceptance rate = 0.3167  for subject 2
# 	phi scelti: (1.356e-01 , 1.193e-03)  marginal y 4.1652e+65
# 	acceptance rate = 0.3700  for subject 3
# 	phi scelti: (1.360e-01 , 3.906e-04)  marginal y 1.0582e+82
# 	acceptance rate = 0.2567  for subject 4
# 	phi scelti: (1.544e-01 , 5.695e-04)  marginal y 6.8206e+59
# 	acceptance rate = 0.1167  for subject 5
# 	phi scelti: (1.519e-01 , 9.516e-04)  marginal y 1.9402e+87
# 	acceptance rate = 0.4067  for subject 6
# 	phi scelti: (1.599e-01 , 4.044e-04)  marginal y 7.5951e+61
#  final_simplex: (array([[1.40769159e-01, 1.17090350e-03, 1.86002588e-02, 7.97387172e-04,
#         2.99999993e-01, 4.99999998e-05],
#        [1.40769170e-01, 1.17090349e-03, 1.86002586e-02, 7.97387166e-04,
#         2.99999991e-01, 4.99999974e-05],
#        [1.40769158e-01, 1.17090349e-03, 1.86002586e-02, 7.97387166e-04,
#         2.99999991e-01, 4.99999974e-05],
#        [1.40769158e-01, 1.17090349e-03, 1.86002586e-02, 7.97387242e-04,
#         2.99999991e-01, 4.99999974e-05],
#        [1.40769158e-01, 1.17090349e-03, 1.86002604e-02, 7.97387166e-04,
#         2.99999991e-01, 4.99999974e-05],
#        [1.40769158e-01, 1.17090360e-03, 1.86002586e-02, 7.97387166e-04,
#         2.99999991e-01, 4.99999974e-05],
#        [1.40769161e-01, 1.17090352e-03, 1.86002591e-02, 7.97387187e-04,
#         2.99999977e-01, 4.99999980e-05]]), array([-1097.07201858, -1097.0719984 , -1097.07199743, -1097.07199712,
#        -1097.07199708, -1097.07199696, -1097.07197427]))
#            fun: -1097.0720185775597
#        message: 'Optimization terminated successfully.'
#           nfev: 163
#            nit: 22
#         status: 0
#        success: True
#              x: array([1.40769159e-01, 1.17090350e-03, 1.86002588e-02, 7.97387172e-04,
#        2.99999993e-01, 4.99999998e-05])
# ### ottimizazione iterazione :  4
# 	acceptance rate = 0.2500  for subject 1
# 	phi scelti: (1.329e-01 , 9.059e-04)  marginal y 1.6459e+75
# 	acceptance rate = 0.3033  for subject 2
# 	phi scelti: (1.574e-01 , 6.283e-04)  marginal y 1.0225e+65
# 	acceptance rate = 0.3333  for subject 3
# 	phi scelti: (1.303e-01 , 3.730e-04)  marginal y 1.6360e+82
# 	acceptance rate = 0.2367  for subject 4
# 	phi scelti: (1.859e-01 , 3.245e-04)  marginal y 7.4930e+59
# 	acceptance rate = 0.0933  for subject 5
# 	phi scelti: (1.279e-01 , 1.178e-03)  marginal y 1.9711e+87
# 	acceptance rate = 0.4667  for subject 6
# 	phi scelti: (1.434e-01 , 7.435e-04)  marginal y 5.1281e+61
#  final_simplex: (array([[1.45909393e-01, 1.17090351e-03, 1.88510765e-02, 7.97387185e-04,
#         2.99999998e-01, 4.99999974e-05],
#        [1.45909391e-01, 1.17090350e-03, 1.88510771e-02, 7.97387172e-04,
#         2.99999993e-01, 4.99999998e-05],
#        [1.45909398e-01, 1.17090350e-03, 1.88510762e-02, 7.97387172e-04,
#         2.99999993e-01, 4.99999998e-05],
#        [1.45909391e-01, 1.17090350e-03, 1.88510762e-02, 7.97387172e-04,
#         2.99999993e-01, 4.99999998e-05],
#        [1.45909391e-01, 1.17090350e-03, 1.88510762e-02, 7.97387210e-04,
#         2.99999993e-01, 4.99999998e-05],
#        [1.45909391e-01, 1.17090355e-03, 1.88510762e-02, 7.97387172e-04,
#         2.99999993e-01, 4.99999998e-05],
#        [1.45909393e-01, 1.17090351e-03, 1.88510765e-02, 7.97387185e-04,
#         2.99999987e-01, 4.99999992e-05]]), array([-539.84893771, -539.84893482, -539.84893482, -539.84893478,
#        -539.84893463, -539.84893453, -539.84892779]))
#            fun: -539.8489377071422
#        message: 'Optimization terminated successfully.'
#           nfev: 171
#            nit: 23
#         status: 0
#        success: True
#              x: array([1.45909393e-01, 1.17090351e-03, 1.88510765e-02, 7.97387185e-04,
#        2.99999998e-01, 4.99999974e-05])
# ### ottimizazione iterazione :  5
# 	acceptance rate = 0.3200  for subject 1
# 	phi scelti: (1.354e-01 , 6.692e-04)  marginal y 6.4088e+74
# 	acceptance rate = 0.2767  for subject 2
# 	phi scelti: (1.764e-01 , 4.827e-04)  marginal y 9.8723e+64
# 	acceptance rate = 0.3933  for subject 3
# 	phi scelti: (1.395e-01 , 2.758e-04)  marginal y 1.0640e+82
# 	acceptance rate = 0.3433  for subject 4
# 	phi scelti: (1.642e-01 , 5.754e-04)  marginal y 9.1278e+59
# 	acceptance rate = 0.1467  for subject 5
# 	phi scelti: (1.451e-01 , 1.086e-03)  marginal y 1.1678e+87
# 	acceptance rate = 0.4333  for subject 6
# 	phi scelti: (1.511e-01 , 6.831e-04)  marginal y 7.1481e+61
#  final_simplex: (array([[1.51949215e-01, 1.17090351e-03, 1.88510765e-02, 7.97387185e-04,
#         2.99999998e-01, 4.99999998e-05],
#        [1.51949215e-01, 1.17090351e-03, 1.88510765e-02, 7.97387185e-04,
#         2.99999998e-01, 4.99999974e-05],
#        [1.51949222e-01, 1.17090351e-03, 1.88510765e-02, 7.97387185e-04,
#         2.99999998e-01, 4.99999974e-05],
#        [1.51949215e-01, 1.17090351e-03, 1.88510774e-02, 7.97387185e-04,
#         2.99999998e-01, 4.99999974e-05],
#        [1.51949215e-01, 1.17090351e-03, 1.88510765e-02, 7.97387223e-04,
#         2.99999998e-01, 4.99999974e-05],
#        [1.51949215e-01, 1.17090357e-03, 1.88510765e-02, 7.97387185e-04,
#         2.99999998e-01, 4.99999974e-05],
#        [1.51949217e-01, 1.17090353e-03, 1.88510767e-02, 7.97387195e-04,
#         2.99999991e-01, 4.99999980e-05]]), array([-428.67739266, -428.6773884 , -428.6773884 , -428.67738828,
#        -428.67738828, -428.67738812, -428.67737022]))
#            fun: -428.67739265998944
#        message: 'Optimization terminated successfully.'
#           nfev: 169
#            nit: 22
#         status: 0
#        success: True
#              x: array([1.51949215e-01, 1.17090351e-03, 1.88510765e-02, 7.97387185e-04,
#        2.99999998e-01, 4.99999998e-05])
# ### ottimizazione iterazione :  6
# 	acceptance rate = 0.2200  for subject 1
# 	phi scelti: (1.336e-01 , 8.794e-04)  marginal y 1.8029e+75
# 	acceptance rate = 0.1833  for subject 2
# 	phi scelti: (1.537e-01 , 4.483e-04)  marginal y 1.5565e+65
# 	acceptance rate = 0.3800  for subject 3
# 	phi scelti: (1.790e-01 , 2.323e-04)  marginal y 1.2311e+82
# 	acceptance rate = 0.2300  for subject 4
# 	phi scelti: (1.481e-01 , 6.126e-04)  marginal y 2.0996e+60
# 	acceptance rate = 0.1133  for subject 5
# 	phi scelti: (1.209e-01 , 1.419e-03)  marginal y 9.4891e+87
# 	acceptance rate = 0.3467  for subject 6
# 	phi scelti: (1.735e-01 , 2.800e-04)  marginal y 7.1825e+61
#  final_simplex: (array([[1.51949216e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999986e-05],
#        [1.51949215e-01, 1.17090351e-03, 1.97936303e-02, 7.97387185e-04,
#         2.99999998e-01, 4.99999998e-05],
#        [1.51949215e-01, 1.17090351e-03, 1.97936301e-02, 7.97387185e-04,
#         2.99999998e-01, 4.99999998e-05],
#        [1.51949217e-01, 1.17090351e-03, 1.97936301e-02, 7.97387185e-04,
#         2.99999998e-01, 4.99999998e-05],
#        [1.51949215e-01, 1.17090351e-03, 1.97936301e-02, 7.97387195e-04,
#         2.99999998e-01, 4.99999998e-05],
#        [1.51949215e-01, 1.17090353e-03, 1.97936301e-02, 7.97387185e-04,
#         2.99999998e-01, 4.99999998e-05],
#        [1.51949216e-01, 1.17090352e-03, 1.97936302e-02, 7.97387189e-04,
#         2.99999997e-01, 4.99999995e-05]]), array([-974.9381248 , -974.93811881, -974.9381188 , -974.93811879,
#        -974.93811878, -974.93811873, -974.93811335]))
#            fun: -974.9381248048645
#        message: 'Optimization terminated successfully.'
#           nfev: 187
#            nit: 25
#         status: 0
#        success: True
#              x: array([1.51949216e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#        3.00000000e-01, 4.99999986e-05])
# ### ottimizazione iterazione :  7
# 	acceptance rate = 0.2200  for subject 1
# 	phi scelti: (1.453e-01 , 9.018e-04)  marginal y 7.7527e+74
# 	acceptance rate = 0.3033  for subject 2
# 	phi scelti: (1.536e-01 , 6.254e-04)  marginal y 1.6488e+65
# 	acceptance rate = 0.3833  for subject 3
# 	phi scelti: (1.533e-01 , 2.862e-04)  marginal y 9.9011e+81
# 	acceptance rate = 0.2567  for subject 4
# 	phi scelti: (1.354e-01 , 7.026e-04)  marginal y 1.1928e+60
# 	acceptance rate = 0.1067  for subject 5
# 	phi scelti: (1.515e-01 , 8.801e-04)  marginal y 4.0006e+87
# 	acceptance rate = 0.4633  for subject 6
# 	phi scelti: (1.576e-01 , 4.497e-04)  marginal y 5.3337e+61
#  final_simplex: (array([[1.51949216e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999998e-05],
#        [1.51949216e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999986e-05],
#        [1.51949216e-01, 1.17090352e-03, 1.97936302e-02, 7.97387209e-04,
#         3.00000000e-01, 4.99999986e-05],
#        [1.51949216e-01, 1.17090352e-03, 1.97936307e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999986e-05],
#        [1.51949219e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999986e-05],
#        [1.51949216e-01, 1.17090355e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999986e-05],
#        [1.51949217e-01, 1.17090353e-03, 1.97936303e-02, 7.97387195e-04,
#         2.99999996e-01, 4.99999989e-05]]), array([-559.42445437, -559.42445086, -559.42445079, -559.42445073,
#        -559.42445072, -559.42445072, -559.42444601]))
#            fun: -559.4244543671216
#        message: 'Optimization terminated successfully.'
#           nfev: 177
#            nit: 23
#         status: 0
#        success: True
#              x: array([1.51949216e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#        3.00000000e-01, 4.99999998e-05])
# ### ottimizazione iterazione :  8
# 	acceptance rate = 0.1900  for subject 1
# 	phi scelti: (1.437e-01 , 7.454e-04)  marginal y 1.2734e+75
# 	acceptance rate = 0.2233  for subject 2
# 	phi scelti: (1.669e-01 , 4.513e-04)  marginal y 1.7384e+65
# 	acceptance rate = 0.4133  for subject 3
# 	phi scelti: (1.578e-01 , 2.743e-04)  marginal y 1.0045e+82
# 	acceptance rate = 0.2867  for subject 4
# 	phi scelti: (1.598e-01 , 4.747e-04)  marginal y 1.9436e+60
# 	acceptance rate = 0.1367  for subject 5
# 	phi scelti: (1.816e-01 , 5.873e-04)  marginal y 1.4596e+87
# 	acceptance rate = 0.4400  for subject 6
# 	phi scelti: (1.610e-01 , 4.485e-04)  marginal y 4.2350e+61
#  final_simplex: (array([[1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546677e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999998e-05],
#        [1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999998e-05],
#        [1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387192e-04,
#         3.00000000e-01, 4.99999998e-05],
#        [1.59546676e-01, 1.17090352e-03, 1.97936303e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999998e-05],
#        [1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999998e-05],
#        [1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         2.99999999e-01, 4.99999999e-05]]), array([-601.48785632, -601.48785632, -601.4878563 , -601.4878563 ,
#        -601.48785629, -601.48785628, -601.48785551]))
#            fun: -601.487856322688
#        message: 'Optimization terminated successfully.'
#           nfev: 201
#            nit: 26
#         status: 0
#        success: True
#              x: array([1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#        3.00000000e-01, 5.00000000e-05])
# ### ottimizazione iterazione :  9
# 	acceptance rate = 0.2867  for subject 1
# 	phi scelti: (1.287e-01 , 9.279e-04)  marginal y 1.8428e+75
# 	acceptance rate = 0.2267  for subject 2
# 	phi scelti: (1.676e-01 , 4.088e-04)  marginal y 1.1449e+65
# 	acceptance rate = 0.3867  for subject 3
# 	phi scelti: (1.818e-01 , 2.807e-04)  marginal y 2.2970e+82
# 	acceptance rate = 0.3133  for subject 4
# 	phi scelti: (1.441e-01 , 5.615e-04)  marginal y 1.2713e+60
# 	acceptance rate = 0.0367  for subject 5
# 	phi scelti: (1.626e-01 , 5.856e-04)  marginal y 1.5605e+87
# 	acceptance rate = 0.4067  for subject 6
# 	phi scelti: (1.715e-01 , 3.802e-04)  marginal y 6.1800e+61
#  final_simplex: (array([[1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999999e-05],
#        [1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05]]), array([-1467.9262579 , -1467.92625785, -1467.92625785, -1467.92625785,
#        -1467.92625785, -1467.92625784, -1467.92625778]))
#            fun: -1467.926257902695
#        message: 'Optimization terminated successfully.'
#           nfev: 219
#            nit: 29
#         status: 0
#        success: True
#              x: array([1.59546676e-01, 1.17090352e-03, 1.97936302e-02, 7.97387190e-04,
#        3.00000000e-01, 4.99999999e-05])
# ### ottimizazione iterazione :  10
# 	acceptance rate = 0.2500  for subject 1
# 	phi scelti: (1.275e-01 , 9.867e-04)  marginal y 9.7870e+74
# 	acceptance rate = 0.2567  for subject 2
# 	phi scelti: (1.349e-01 , 7.748e-04)  marginal y 2.8499e+65
# 	acceptance rate = 0.4000  for subject 3
# 	phi scelti: (1.249e-01 , 5.237e-04)  marginal y 1.5443e+82
# 	acceptance rate = 0.2700  for subject 4
# 	phi scelti: (1.543e-01 , 6.607e-04)  marginal y 1.0357e+60
# 	acceptance rate = 0.0733  for subject 5
# 	phi scelti: (1.594e-01 , 9.942e-04)  marginal y 1.6292e+87
# 	acceptance rate = 0.4267  for subject 6
# 	phi scelti: (1.674e-01 , 3.715e-04)  marginal y 5.9831e+61
#  final_simplex: (array([[1.59546676e-01, 1.17090352e-03, 2.07833117e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546676e-01, 1.17090352e-03, 2.07833117e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999999e-05],
#        [1.59546676e-01, 1.17090352e-03, 2.07833117e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999999e-05],
#        [1.59546676e-01, 1.17090352e-03, 2.07833117e-02, 7.97387191e-04,
#         3.00000000e-01, 4.99999999e-05],
#        [1.59546676e-01, 1.17090352e-03, 2.07833117e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999999e-05],
#        [1.59546676e-01, 1.17090352e-03, 2.07833117e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999999e-05],
#        [1.59546676e-01, 1.17090352e-03, 2.07833117e-02, 7.97387190e-04,
#         3.00000000e-01, 4.99999999e-05]]), array([-1151.15775077, -1151.15775073, -1151.15775073, -1151.15775073,
#        -1151.15775073, -1151.15775071, -1151.15775044]))
#            fun: -1151.1577507747884
#        message: 'Optimization terminated successfully.'
#           nfev: 217
#            nit: 28
#         status: 0
#        success: True
#              x: array([1.59546676e-01, 1.17090352e-03, 2.07833117e-02, 7.97387190e-04,
#        3.00000000e-01, 5.00000000e-05])
# ### ottimizazione iterazione :  11
# 	acceptance rate = 0.2767  for subject 1
# 	phi scelti: (1.449e-01 , 6.319e-04)  marginal y 1.1663e+75
# 	acceptance rate = 0.2733  for subject 2
# 	phi scelti: (1.654e-01 , 5.794e-04)  marginal y 1.5632e+65
# 	acceptance rate = 0.4700  for subject 3
# 	phi scelti: (1.276e-01 , 4.755e-04)  marginal y 1.7546e+82
# 	acceptance rate = 0.2900  for subject 4
# 	phi scelti: (1.838e-01 , 3.904e-04)  marginal y 1.3010e+60
# 	acceptance rate = 0.0933  for subject 5
# 	phi scelti: (1.800e-01 , 6.959e-04)  marginal y 2.9567e+86
# 	acceptance rate = 0.4100  for subject 6
# 	phi scelti: (1.240e-01 , 7.044e-04)  marginal y 5.1257e+61
#  final_simplex: (array([[1.59546676e-01, 1.21481240e-03, 2.10431031e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546676e-01, 1.21481240e-03, 2.10431031e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546676e-01, 1.21481240e-03, 2.10431031e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546676e-01, 1.21481240e-03, 2.10431031e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546676e-01, 1.21481240e-03, 2.10431031e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546676e-01, 1.21481240e-03, 2.10431031e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.59546676e-01, 1.21481240e-03, 2.10431031e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05]]), array([-1591.79898442, -1591.79898441, -1591.7989844 , -1591.7989844 ,
#        -1591.7989844 , -1591.79898439, -1591.79898437]))
#            fun: -1591.798984420745
#        message: 'Optimization terminated successfully.'
#           nfev: 225
#            nit: 29
#         status: 0
#        success: True
#              x: array([1.59546676e-01, 1.21481240e-03, 2.10431031e-02, 7.97387190e-04,
#        3.00000000e-01, 5.00000000e-05])
# ### ottimizazione iterazione :  12
# 	acceptance rate = 0.2833  for subject 1
# 	phi scelti: (1.257e-01 , 8.027e-04)  marginal y 7.7658e+74
# 	acceptance rate = 0.2467  for subject 2
# 	phi scelti: (1.298e-01 , 9.046e-04)  marginal y 4.2754e+65
# 	acceptance rate = 0.4733  for subject 3
# 	phi scelti: (1.486e-01 , 2.758e-04)  marginal y 1.0301e+82
# 	acceptance rate = 0.2967  for subject 4
# 	phi scelti: (1.693e-01 , 5.414e-04)  marginal y 1.3958e+60
# 	acceptance rate = 0.1600  for subject 5
# 	phi scelti: (1.470e-01 , 9.126e-04)  marginal y 3.2825e+87
# 	acceptance rate = 0.4600  for subject 6
# 	phi scelti: (1.214e-01 , 6.890e-04)  marginal y 4.0617e+61
#  final_simplex: (array([[1.65529677e-01, 1.21481241e-03, 2.11746225e-02, 7.97387191e-04,
#         2.99999999e-01, 4.99999999e-05],
#        [1.65529676e-01, 1.21481240e-03, 2.11746225e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.65529676e-01, 1.21481241e-03, 2.11746225e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.65529676e-01, 1.21481240e-03, 2.11746225e-02, 7.97387191e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.65529676e-01, 1.21481240e-03, 2.11746225e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05],
#        [1.65529677e-01, 1.21481240e-03, 2.11746225e-02, 7.97387191e-04,
#         3.00000000e-01, 4.99999999e-05],
#        [1.65529677e-01, 1.21481240e-03, 2.11746225e-02, 7.97387190e-04,
#         3.00000000e-01, 5.00000000e-05]]), array([-1588.57355319, -1588.57355314, -1588.57355311, -1588.57355311,
#        -1588.5735531 , -1588.57355309, -1588.57355296]))
#            fun: -1588.5735531928829
#        message: 'Optimization terminated successfully.'
#           nfev: 210
#            nit: 28
#         status: 0
#        success: True
#              x: array([1.65529677e-01, 1.21481241e-03, 2.11746225e-02, 7.97387191e-04,
#        2.99999999e-01, 4.99999999e-05])
# ### ottimizazione iterazione :  13
# 	acceptance rate = 0.1933  for subject 1
# 	phi scelti: (1.514e-01 , 6.519e-04)  marginal y 9.3387e+74
# 	acceptance rate = 0.2900  for subject 2
# 	phi scelti: (1.488e-01 , 1.108e-03)  marginal y 2.0721e+65
# 	acceptance rate = 0.4633  for subject 3
# 	phi scelti: (1.325e-01 , 4.599e-04)  marginal y 1.2755e+82
# 	acceptance rate = 0.2967  for subject 4
# 	phi scelti: (1.496e-01 , 5.558e-04)  marginal y 1.2355e+60
# 	acceptance rate = 0.1533  for subject 5
# 	phi scelti: (1.436e-01 , 9.103e-04)  marginal y 1.6311e+87
# 	acceptance rate = 0.4400  for subject 6
# 	phi scelti: (1.448e-01 , 4.638e-04)  marginal y 6.2328e+61
#  final_simplex: (array([[1.65529677e-01, 1.26416416e-03, 2.13731345e-02, 7.97387194e-04,
#         2.99999996e-01, 4.99999998e-05],
#        [1.65529677e-01, 1.26416416e-03, 2.13731346e-02, 7.97387191e-04,
#         2.99999999e-01, 4.99999999e-05],
#        [1.65529677e-01, 1.26416417e-03, 2.13731345e-02, 7.97387191e-04,
#         2.99999999e-01, 4.99999999e-05],
#        [1.65529677e-01, 1.26416416e-03, 2.13731345e-02, 7.97387196e-04,
#         2.99999999e-01, 4.99999999e-05],
#        [1.65529677e-01, 1.26416416e-03, 2.13731345e-02, 7.97387191e-04,
#         2.99999999e-01, 4.99999999e-05],
#        [1.65529677e-01, 1.26416416e-03, 2.13731345e-02, 7.97387193e-04,
#         3.00000000e-01, 4.99999996e-05],
#        [1.65529678e-01, 1.26416416e-03, 2.13731345e-02, 7.97387191e-04,
#         2.99999999e-01, 4.99999999e-05]]), array([-1588.99016686, -1588.99016664, -1588.99016653, -1588.99016653,
#        -1588.9901665 , -1588.99016645, -1588.99016592]))
#            fun: -1588.990166863623
#        message: 'Optimization terminated successfully.'
#           nfev: 194
#            nit: 26
#         status: 0
#        success: True
#              x: array([1.65529677e-01, 1.26416416e-03, 2.13731345e-02, 7.97387194e-04,
#        2.99999996e-01, 4.99999998e-05])
# ### ottimizazione iterazione :  14
# 	acceptance rate = 0.2067  for subject 1
# 	phi scelti: (1.517e-01 , 5.086e-04)  marginal y 5.7374e+74
# 	acceptance rate = 0.3533  for subject 2
# 	phi scelti: (1.347e-01 , 8.911e-04)  marginal y 2.7376e+65
# 	acceptance rate = 0.4367  for subject 3
# 	phi scelti: (1.693e-01 , 2.392e-04)  marginal y 1.2452e+82
# 	acceptance rate = 0.3167  for subject 4
# 	phi scelti: (1.537e-01 , 8.344e-04)  marginal y 1.2178e+60
# 	acceptance rate = 0.1467  for subject 5
# 	phi scelti: (1.374e-01 , 1.055e-03)  marginal y 2.6105e+87
# 	acceptance rate = 0.4033  for subject 6
# 	phi scelti: (1.745e-01 , 3.895e-04)  marginal y 5.3075e+61
#  final_simplex: (array([[1.65529680e-01, 1.27206521e-03, 2.23082090e-02, 7.97387207e-04,
#         2.99999983e-01, 4.99999992e-05],
#        [1.65529677e-01, 1.27206519e-03, 2.23082092e-02, 7.97387194e-04,
#         2.99999996e-01, 4.99999998e-05],
#        [1.65529677e-01, 1.27206522e-03, 2.23082087e-02, 7.97387194e-04,
#         2.99999996e-01, 4.99999998e-05],
#        [1.65529677e-01, 1.27206519e-03, 2.23082087e-02, 7.97387213e-04,
#         2.99999996e-01, 4.99999998e-05],
#        [1.65529677e-01, 1.27206519e-03, 2.23082087e-02, 7.97387194e-04,
#         2.99999996e-01, 4.99999998e-05],
#        [1.65529679e-01, 1.27206520e-03, 2.23082088e-02, 7.97387200e-04,
#         2.99999998e-01, 4.99999986e-05],
#        [1.65529681e-01, 1.27206519e-03, 2.23082087e-02, 7.97387194e-04,
#         2.99999996e-01, 4.99999998e-05]]), array([-1589.9983718 , -1589.99837076, -1589.99837037, -1589.99837037,
#        -1589.99837027, -1589.99837011, -1589.99836814]))
#            fun: -1589.998371796585
#        message: 'Optimization terminated successfully.'
#           nfev: 178
#            nit: 24
#         status: 0
#        success: True
#              x: array([1.65529680e-01, 1.27206521e-03, 2.23082090e-02, 7.97387207e-04,
#        2.99999983e-01, 4.99999992e-05])
# ### ottimizazione iterazione :  15
# 	acceptance rate = 0.2767  for subject 1
# 	phi scelti: (1.533e-01 , 5.839e-04)  marginal y 1.6288e+75
# 	acceptance rate = 0.2033  for subject 2
# 	phi scelti: (1.560e-01 , 7.964e-04)  marginal y 3.5588e+65
# 	acceptance rate = 0.4067  for subject 3
# 	phi scelti: (1.617e-01 , 3.200e-04)  marginal y 1.7517e+82
# 	acceptance rate = 0.3000  for subject 4
# 	phi scelti: (1.623e-01 , 7.076e-04)  marginal y 1.7726e+60
# 	acceptance rate = 0.1700  for subject 5
# 	phi scelti: (1.523e-01 , 6.282e-04)  marginal y 2.0638e+87
# 	acceptance rate = 0.4467  for subject 6
# 	phi scelti: (1.555e-01 , 4.417e-04)  marginal y 5.0251e+61
#  final_simplex: (array([[1.66564251e-01, 1.27206529e-03, 2.24476346e-02, 8.27289278e-04,
#         2.99999930e-01, 4.99999968e-05],
#        [1.66564240e-01, 1.27206521e-03, 2.24476353e-02, 8.27289227e-04,
#         2.99999983e-01, 4.99999992e-05],
#        [1.66564240e-01, 1.27206533e-03, 2.24476332e-02, 8.27289227e-04,
#         2.99999983e-01, 4.99999992e-05],
#        [1.66564240e-01, 1.27206521e-03, 2.24476332e-02, 8.27289303e-04,
#         2.99999983e-01, 4.99999992e-05],
#        [1.66564240e-01, 1.27206521e-03, 2.24476332e-02, 8.27289227e-04,
#         2.99999983e-01, 4.99999992e-05],
#        [1.66564246e-01, 1.27206525e-03, 2.24476339e-02, 8.27289252e-04,
#         2.99999992e-01, 4.99999944e-05],
#        [1.66564256e-01, 1.27206521e-03, 2.24476332e-02, 8.27289227e-04,
#         2.99999983e-01, 4.99999992e-05]]), array([-1589.71675223, -1589.71674828, -1589.71674655, -1589.71674647,
#        -1589.71674615, -1589.71674548, -1589.71673755]))
#            fun: -1589.7167522272468
#        message: 'Optimization terminated successfully.'
#           nfev: 162
#            nit: 22
#         status: 0
#        success: True
#              x: array([1.66564251e-01, 1.27206529e-03, 2.24476346e-02, 8.27289278e-04,
#        2.99999930e-01, 4.99999968e-05])
# ### ottimizazione iterazione :  16
# 	acceptance rate = 0.2233  for subject 1
# 	phi scelti: (1.180e-01 , 1.228e-03)  marginal y 6.3827e+75
# 	acceptance rate = 0.2933  for subject 2
# 	phi scelti: (1.547e-01 , 5.316e-04)  marginal y 3.3448e+65
# 	acceptance rate = 0.3267  for subject 3
# 	phi scelti: (1.597e-01 , 3.106e-04)  marginal y 7.4572e+81
# 	acceptance rate = 0.2967  for subject 4
# 	phi scelti: (1.555e-01 , 5.488e-04)  marginal y 1.4739e+60
# 	acceptance rate = 0.1333  for subject 5
# 	phi scelti: (1.553e-01 , 9.313e-04)  marginal y 6.8248e+87
# 	acceptance rate = 0.4567  for subject 6
# 	phi scelti: (1.555e-01 , 4.417e-04)  marginal y 2.9861e+61
#  final_simplex: (array([[1.68646346e-01, 1.27206561e-03, 2.26580783e-02, 8.27289488e-04,
#         2.99999720e-01, 4.99999873e-05],
#        [1.68646304e-01, 1.27206529e-03, 2.26580812e-02, 8.27289278e-04,
#         2.99999930e-01, 4.99999968e-05],
#        [1.68646304e-01, 1.27206578e-03, 2.26580726e-02, 8.27289278e-04,
#         2.99999930e-01, 4.99999968e-05],
#        [1.68646304e-01, 1.27206529e-03, 2.26580726e-02, 8.27289593e-04,
#         2.99999930e-01, 4.99999968e-05],
#        [1.68646304e-01, 1.27206529e-03, 2.26580726e-02, 8.27289278e-04,
#         2.99999930e-01, 4.99999968e-05],
#        [1.68646325e-01, 1.27206545e-03, 2.26580755e-02, 8.27289383e-04,
#         2.99999968e-01, 4.99999777e-05],
#        [1.68646368e-01, 1.27206529e-03, 2.26580726e-02, 8.27289278e-04,
#         2.99999930e-01, 4.99999968e-05]]), array([-1588.78571103, -1588.78569616, -1588.7856886 , -1588.78568834,
#        -1588.78568701, -1588.78568419, -1588.78565151]))
#            fun: -1588.7857110333575
#        message: 'Optimization terminated successfully.'
#           nfev: 146
#            nit: 20
#         status: 0
#        success: True
#              x: array([1.68646346e-01, 1.27206561e-03, 2.26580783e-02, 8.27289488e-04,
#        2.99999720e-01, 4.99999873e-05])
# ### ottimizazione iterazione :  17
# 	acceptance rate = 0.2033  for subject 1
# 	phi scelti: (1.231e-01 , 1.166e-03)  marginal y 1.5748e+75
# 	acceptance rate = 0.2000  for subject 2
# 	phi scelti: (1.547e-01 , 5.316e-04)  marginal y 3.4536e+65
# 	acceptance rate = 0.3400  for subject 3
# 	phi scelti: (1.610e-01 , 2.414e-04)  marginal y 1.3517e+82
# 	acceptance rate = 0.2833  for subject 4
# 	phi scelti: (2.088e-01 , 4.359e-04)  marginal y 1.5766e+60
# 	acceptance rate = 0.1233  for subject 5
# 	phi scelti: (1.520e-01 , 9.362e-04)  marginal y 2.3167e+87
# 	acceptance rate = 0.3767  for subject 6
# 	phi scelti: (1.975e-01 , 2.826e-04)  marginal y 5.6902e+61
#  final_simplex: (array([[1.16290743e-01, 1.46852005e-03, 2.96265146e-02, 1.00788676e-03,
#         1.98922275e-01, 4.44674689e-05],
#        [1.16330035e-01, 1.46838864e-03, 2.96214292e-02, 1.00775803e-03,
#         1.98993156e-01, 4.44716861e-05],
#        [1.16317245e-01, 1.46841410e-03, 2.96251666e-02, 1.00792309e-03,
#         1.98875541e-01, 4.44710849e-05],
#        [1.16350102e-01, 1.46831221e-03, 2.96200849e-02, 1.00776495e-03,
#         1.98973270e-01, 4.44742764e-05],
#        [1.16275396e-01, 1.46857164e-03, 2.96277041e-02, 1.00789848e-03,
#         1.98926197e-01, 4.44656726e-05],
#        [1.16376546e-01, 1.46819954e-03, 2.96204003e-02, 1.00789020e-03,
#         1.98856189e-01, 4.44783403e-05],
#        [1.16387890e-01, 1.46817453e-03, 2.96169433e-02, 1.00774030e-03,
#         1.98964378e-01, 4.44789017e-05]]), array([-1616.02502018, -1616.02500263, -1616.02499786, -1616.02499704,
#        -1616.02499597, -1616.02498402, -1616.02497967]))
#            fun: -1616.0250201805177
#        message: 'Optimization terminated successfully.'
#           nfev: 476
#            nit: 236
#         status: 0
#        success: True
#              x: array([1.16290743e-01, 1.46852005e-03, 2.96265146e-02, 1.00788676e-03,
#        1.98922275e-01, 4.44674689e-05])
# ### ottimizazione iterazione :  18
# 	acceptance rate = 0.2833  for subject 1
# 	phi scelti: (1.248e-01 , 1.230e-03)  marginal y 2.7477e+76
# 	acceptance rate = 0.3333  for subject 2
# 	phi scelti: (1.354e-01 , 1.302e-03)  marginal y 2.0558e+66
# 	acceptance rate = 0.3933  for subject 3
# 	phi scelti: (1.273e-01 , 4.272e-04)  marginal y 5.0058e+83
# 	acceptance rate = 0.3200  for subject 4
# 	phi scelti: (1.392e-01 , 7.494e-04)  marginal y 3.8629e+61
# 	acceptance rate = 0.1600  for subject 5
# 	phi scelti: (1.233e-01 , 1.215e-03)  marginal y 1.1561e+90
# 	acceptance rate = 0.5400  for subject 6
# 	phi scelti: (1.198e-01 , 9.438e-04)  marginal y 7.6107e+62
#  final_simplex: (array([[1.20846934e-01, 1.64664423e-03, 1.72407813e-02, 9.70279140e-04,
#         1.97557096e-01, 4.05932205e-05],
#        [1.20865121e-01, 1.64552540e-03, 1.72416464e-02, 9.69750803e-04,
#         1.97576691e-01, 4.05790970e-05],
#        [1.20860173e-01, 1.64555340e-03, 1.72379847e-02, 9.71101907e-04,
#         1.97471184e-01, 4.05877652e-05],
#        [1.20841922e-01, 1.64502144e-03, 1.72221409e-02, 9.69869127e-04,
#         1.97597367e-01, 4.06036013e-05],
#        [1.20826317e-01, 1.64518965e-03, 1.72598903e-02, 9.69454529e-04,
#         1.97503019e-01, 4.05781926e-05],
#        [1.20851681e-01, 1.64547092e-03, 1.72603606e-02, 9.68854491e-04,
#         1.97558226e-01, 4.06038066e-05],
#        [1.20846977e-01, 1.64523450e-03, 1.72686535e-02, 9.71325306e-04,
#         1.97458124e-01, 4.05800412e-05]]), array([-1618.13492371, -1618.13491526, -1618.13490802, -1618.1349076 ,
#        -1618.13490698, -1618.13490093, -1618.13490041]))
#            fun: -1618.134923712312
#        message: 'Optimization terminated successfully.'
#           nfev: 281
#            nit: 178
#         status: 0
#        success: True
#              x: array([1.20846934e-01, 1.64664423e-03, 1.72407813e-02, 9.70279140e-04,
#        1.97557096e-01, 4.05932205e-05])
# ### ottimizazione iterazione :  19
# 	acceptance rate = 0.2400  for subject 1
# 	phi scelti: (1.226e-01 , 1.199e-03)  marginal y 9.0595e+76
# 	acceptance rate = 0.2067  for subject 2
# 	phi scelti: (1.385e-01 , 9.190e-04)  marginal y 1.4388e+67
# 	acceptance rate = 0.3667  for subject 3
# 	phi scelti: (1.103e-01 , 7.929e-04)  marginal y 9.6038e+83
# 	acceptance rate = 0.3467  for subject 4
# 	phi scelti: (1.355e-01 , 7.867e-04)  marginal y 7.8985e+61
# 	acceptance rate = 0.1233  for subject 5
# 	phi scelti: (1.261e-01 , 1.479e-03)  marginal y 4.1183e+90
# 	acceptance rate = 0.4333  for subject 6
# 	phi scelti: (1.224e-01 , 9.498e-04)  marginal y 1.9023e+63
#  final_simplex: (array([[1.20848923e-01, 1.64040380e-03, 1.72000985e-02, 9.68701251e-04,
#         1.97337575e-01, 4.05851513e-05],
#        [1.20799830e-01, 1.64079117e-03, 1.72283440e-02, 9.70758745e-04,
#         1.97255403e-01, 4.05944842e-05],
#        [1.20794298e-01, 1.64091716e-03, 1.72294932e-02, 9.70593931e-04,
#         1.97272523e-01, 4.05644986e-05],
#        [1.20839583e-01, 1.64344738e-03, 1.72237069e-02, 9.66170489e-04,
#         1.97307198e-01, 4.05817441e-05],
#        [1.20786602e-01, 1.63981676e-03, 1.72090100e-02, 9.69632789e-04,
#         1.97268873e-01, 4.05856498e-05],
#        [1.20861475e-01, 1.63923532e-03, 1.72473541e-02, 9.69291928e-04,
#         1.97270122e-01, 4.05613344e-05],
#        [1.20751981e-01, 1.63725807e-03, 1.72614421e-02, 9.68594042e-04,
#         1.97381343e-01, 4.05850695e-05]]), array([-1618.13467198, -1618.13464535, -1618.13463262, -1618.13461333,
#        -1618.13458687, -1618.13457756, -1618.13457576]))
#            fun: -1618.1346719808978
#        message: 'Optimization terminated successfully.'
#           nfev: 224
#            nit: 143
#         status: 0
#        success: True
#              x: array([1.20848923e-01, 1.64040380e-03, 1.72000985e-02, 9.68701251e-04,
#        1.97337575e-01, 4.05851513e-05])
# ### ottimizazione iterazione :  20
# 	acceptance rate = 0.3233  for subject 1
# 	phi scelti: (1.042e-01 , 1.837e-03)  marginal y 1.2942e+77
# 	acceptance rate = 0.2433  for subject 2
# 	phi scelti: (1.280e-01 , 1.192e-03)  marginal y 8.3099e+66
# 	acceptance rate = 0.4267  for subject 3
# 	phi scelti: (1.433e-01 , 4.678e-04)  marginal y 1.3710e+84
# 	acceptance rate = 0.2467  for subject 4
# 	phi scelti: (1.301e-01 , 8.639e-04)  marginal y 5.4016e+61
# 	acceptance rate = 0.2000  for subject 5
# 	phi scelti: (1.161e-01 , 1.776e-03)  marginal y 1.9865e+90
# 	acceptance rate = 0.4367  for subject 6
# 	phi scelti: (1.185e-01 , 1.142e-03)  marginal y 1.3295e+63
#  final_simplex: (array([[1.20837777e-01, 1.64612995e-03, 1.72494960e-02, 9.71889969e-04,
#         1.97578207e-01, 4.05878500e-05],
#        [1.20825956e-01, 1.64531002e-03, 1.72483106e-02, 9.72101348e-04,
#         1.97605398e-01, 4.05919691e-05],
#        [1.20832749e-01, 1.64495446e-03, 1.72507927e-02, 9.71643955e-04,
#         1.97554816e-01, 4.05769736e-05],
#        [1.20835111e-01, 1.64452718e-03, 1.72631738e-02, 9.71980174e-04,
#         1.97525578e-01, 4.05949955e-05],
#        [1.20856985e-01, 1.64503928e-03, 1.72495852e-02, 9.72166938e-04,
#         1.97593949e-01, 4.05956298e-05],
#        [1.20811790e-01, 1.64540758e-03, 1.72432850e-02, 9.72189702e-04,
#         1.97546938e-01, 4.05945484e-05],
#        [1.20846611e-01, 1.64459060e-03, 1.72591410e-02, 9.71321171e-04,
#         1.97495836e-01, 4.06078474e-05]]), array([-1618.13493117, -1618.13493092, -1618.13493015, -1618.13492934,
#        -1618.13492871, -1618.13492214, -1618.134913  ]))
#            fun: -1618.1349311716874
#        message: 'Optimization terminated successfully.'
#           nfev: 156
#            nit: 90
#         status: 0
#        success: True
#              x: array([1.20837777e-01, 1.64612995e-03, 1.72494960e-02, 9.71889969e-04,
#        1.97578207e-01, 4.05878500e-05])
# ### ottimizazione iterazione :  21
# 	acceptance rate = 0.2333  for subject 1
# 	phi scelti: (1.038e-01 , 1.915e-03)  marginal y 1.2925e+77
# 	acceptance rate = 0.3567  for subject 2
# 	phi scelti: (1.193e-01 , 1.325e-03)  marginal y 7.6009e+66
# 	acceptance rate = 0.4167  for subject 3
# 	phi scelti: (1.437e-01 , 3.159e-04)  marginal y 1.3012e+84
# 	acceptance rate = 0.3100  for subject 4
# 	phi scelti: (1.401e-01 , 8.240e-04)  marginal y 8.0865e+61
# 	acceptance rate = 0.2133  for subject 5
# 	phi scelti: (1.191e-01 , 1.485e-03)  marginal y 1.2826e+90
# 	acceptance rate = 0.4733  for subject 6
# 	phi scelti: (1.382e-01 , 6.434e-04)  marginal y 1.4641e+63
#  final_simplex: (array([[1.20834508e-01, 1.63851444e-03, 1.72185335e-02, 9.70316956e-04,
#         1.97487762e-01, 4.05859496e-05],
#        [1.20801168e-01, 1.63850818e-03, 1.72474145e-02, 9.70180188e-04,
#         1.97455261e-01, 4.05815313e-05],
#        [1.20842032e-01, 1.63843130e-03, 1.72450394e-02, 9.68790594e-04,
#         1.97481697e-01, 4.06047825e-05],
#        [1.20818889e-01, 1.63895160e-03, 1.72505383e-02, 9.68504428e-04,
#         1.97572671e-01, 4.05625575e-05],
#        [1.20838920e-01, 1.63773571e-03, 1.72474392e-02, 9.69764878e-04,
#         1.97463750e-01, 4.05799057e-05],
#        [1.20848902e-01, 1.63768848e-03, 1.72535149e-02, 9.68756424e-04,
#         1.97506417e-01, 4.05968148e-05],
#        [1.20790644e-01, 1.63777285e-03, 1.72397468e-02, 9.69459415e-04,
#         1.97500540e-01, 4.05996630e-05]]), array([-1618.13478161, -1618.13477172, -1618.13476109, -1618.13475788,
#        -1618.13475025, -1618.13474615, -1618.13473855]))
#            fun: -1618.134781608852
#        message: 'Optimization terminated successfully.'
#           nfev: 132
#            nit: 68
#         status: 0
#        success: True
#              x: array([1.20834508e-01, 1.63851444e-03, 1.72185335e-02, 9.70316956e-04,
#        1.97487762e-01, 4.05859496e-05])
# ### ottimizazione iterazione :  22
# 	acceptance rate = 0.2467  for subject 1
# 	phi scelti: (1.086e-01 , 1.450e-03)  marginal y 1.1926e+77
# 	acceptance rate = 0.1933  for subject 2
# 	phi scelti: (1.347e-01 , 9.863e-04)  marginal y 4.9791e+66
# 	acceptance rate = 0.3633  for subject 3
# 	phi scelti: (1.375e-01 , 4.975e-04)  marginal y 1.1420e+84
# 	acceptance rate = 0.2833  for subject 4
# 	phi scelti: (1.437e-01 , 7.834e-04)  marginal y 1.1110e+62
# 	acceptance rate = 0.1800  for subject 5
# 	phi scelti: (1.125e-01 , 1.954e-03)  marginal y 4.0504e+90
# 	acceptance rate = 0.4033  for subject 6
# 	phi scelti: (1.382e-01 , 6.434e-04)  marginal y 2.4202e+63
#  final_simplex: (array([[1.20818517e-01, 1.64180206e-03, 1.71680598e-02, 9.71951665e-04,
#         1.97622331e-01, 4.05741865e-05],
#        [1.20841130e-01, 1.64001359e-03, 1.71794356e-02, 9.70928307e-04,
#         1.97692243e-01, 4.05838578e-05],
#        [1.20799414e-01, 1.63995485e-03, 1.71850720e-02, 9.70932920e-04,
#         1.97698898e-01, 4.05882882e-05],
#        [1.20783723e-01, 1.64023789e-03, 1.71830539e-02, 9.70227467e-04,
#         1.97656646e-01, 4.06026512e-05],
#        [1.20836469e-01, 1.63864858e-03, 1.71834140e-02, 9.71594070e-04,
#         1.97605652e-01, 4.05733304e-05],
#        [1.20804732e-01, 1.63878925e-03, 1.71784333e-02, 9.71961540e-04,
#         1.97640350e-01, 4.05780253e-05],
#        [1.20852760e-01, 1.64141130e-03, 1.71602843e-02, 9.71962627e-04,
#         1.97547046e-01, 4.06201552e-05]]), array([-1618.13474494, -1618.13473533, -1618.13473374, -1618.13473012,
#        -1618.13471363, -1618.13468975, -1618.13468306]))
#            fun: -1618.134744939817
#        message: 'Optimization terminated successfully.'
#           nfev: 136
#            nit: 76
#         status: 0
#        success: True
#              x: array([1.20818517e-01, 1.64180206e-03, 1.71680598e-02, 9.71951665e-04,
#        1.97622331e-01, 4.05741865e-05])
# ### ottimizazione iterazione :  23
# 	acceptance rate = 0.2900  for subject 1
# 	phi scelti: (1.004e-01 , 2.491e-03)  marginal y 1.5723e+77
# 	acceptance rate = 0.2367  for subject 2
# 	phi scelti: (1.207e-01 , 1.288e-03)  marginal y 5.9633e+66
# 	acceptance rate = 0.4233  for subject 3
# 	phi scelti: (1.288e-01 , 5.720e-04)  marginal y 8.5035e+83
# 	acceptance rate = 0.2933  for subject 4
# 	phi scelti: (1.299e-01 , 1.059e-03)  marginal y 7.0906e+61
# 	acceptance rate = 0.1033  for subject 5
# 	phi scelti: (1.398e-01 , 8.274e-04)  marginal y 2.8423e+90
# 	acceptance rate = 0.4600  for subject 6
# 	phi scelti: (1.467e-01 , 7.162e-04)  marginal y 1.0609e+63
#  final_simplex: (array([[1.20859039e-01, 1.64551263e-03, 1.71235018e-02, 9.69653150e-04,
#         1.97640849e-01, 4.05927928e-05],
#        [1.20844354e-01, 1.64421898e-03, 1.71275983e-02, 9.69410153e-04,
#         1.97710107e-01, 4.05792230e-05],
#        [1.20850825e-01, 1.64421521e-03, 1.71131955e-02, 9.70988180e-04,
#         1.97542158e-01, 4.05976426e-05],
#        [1.20859402e-01, 1.64548008e-03, 1.71192756e-02, 9.70745921e-04,
#         1.97648728e-01, 4.05699973e-05],
#        [1.20834692e-01, 1.64496206e-03, 1.71074585e-02, 9.70407047e-04,
#         1.97560256e-01, 4.05969526e-05],
#        [1.20784849e-01, 1.64454848e-03, 1.71148017e-02, 9.70729019e-04,
#         1.97680604e-01, 4.05859457e-05],
#        [1.20854528e-01, 1.64360056e-03, 1.71064953e-02, 9.71264794e-04,
#         1.97635732e-01, 4.05935626e-05]]), array([-1618.13457628, -1618.13456207, -1618.13454037, -1618.13453953,
#        -1618.13450902, -1618.13450203, -1618.13449272]))
#            fun: -1618.1345762773783
#        message: 'Optimization terminated successfully.'
#           nfev: 152
#            nit: 90
#         status: 0
#        success: True
#              x: array([1.20859039e-01, 1.64551263e-03, 1.71235018e-02, 9.69653150e-04,
#        1.97640849e-01, 4.05927928e-05])
# ### ottimizazione iterazione :  24
# 	acceptance rate = 0.2267  for subject 1
# 	phi scelti: (1.135e-01 , 1.293e-03)  marginal y 1.6666e+77
# 	acceptance rate = 0.2700  for subject 2
# 	phi scelti: (1.062e-01 , 2.176e-03)  marginal y 2.2424e+67
# 	acceptance rate = 0.4533  for subject 3
# 	phi scelti: (1.339e-01 , 4.451e-04)  marginal y 8.8105e+83
# 	acceptance rate = 0.3333  for subject 4
# 	phi scelti: (1.464e-01 , 8.834e-04)  marginal y 6.7730e+61
# 	acceptance rate = 0.1533  for subject 5
# 	phi scelti: (1.331e-01 , 1.051e-03)  marginal y 1.6518e+90
# 	acceptance rate = 0.4167  for subject 6
# 	phi scelti: (1.119e-01 , 1.023e-03)  marginal y 2.1548e+63
#  final_simplex: (array([[1.20818777e-01, 1.64800615e-03, 1.72717733e-02, 9.72689153e-04,
#         1.97530392e-01, 4.05989842e-05],
#        [1.20816882e-01, 1.64641659e-03, 1.73007206e-02, 9.69035841e-04,
#         1.97571031e-01, 4.05864771e-05],
#        [1.20853112e-01, 1.64931914e-03, 1.72676628e-02, 9.69786932e-04,
#         1.97562222e-01, 4.05877395e-05],
#        [1.20877553e-01, 1.64647578e-03, 1.72463510e-02, 9.69034989e-04,
#         1.97494155e-01, 4.05691349e-05],
#        [1.20854902e-01, 1.64829761e-03, 1.72912082e-02, 9.70602565e-04,
#         1.97522281e-01, 4.05720766e-05],
#        [1.20903999e-01, 1.64591117e-03, 1.72798409e-02, 9.68579763e-04,
#         1.97605518e-01, 4.05998855e-05],
#        [1.20846171e-01, 1.64863146e-03, 1.72629768e-02, 9.71836025e-04,
#         1.97608924e-01, 4.05591106e-05]]), array([-1618.13487048, -1618.13485863, -1618.13485734, -1618.13485403,
#        -1618.13484333, -1618.13483695, -1618.13483078]))
#            fun: -1618.134870478821
#        message: 'Optimization terminated successfully.'
#           nfev: 166
#            nit: 101
#         status: 0
#        success: True
#              x: array([1.20818777e-01, 1.64800615e-03, 1.72717733e-02, 9.72689153e-04,
#        1.97530392e-01, 4.05989842e-05])
# ### ottimizazione iterazione :  25
# 	acceptance rate = 0.2533  for subject 1
# 	phi scelti: (1.205e-01 , 1.204e-03)  marginal y 1.5254e+77
# 	acceptance rate = 0.3067  for subject 2
# 	phi scelti: (1.157e-01 , 1.648e-03)  marginal y 8.5963e+66
# 	acceptance rate = 0.4333  for subject 3
# 	phi scelti: (1.339e-01 , 4.451e-04)  marginal y 1.1821e+84
# 	acceptance rate = 0.3700  for subject 4
# 	phi scelti: (1.140e-01 , 1.803e-03)  marginal y 9.0854e+61
# 	acceptance rate = 0.1700  for subject 5
# 	phi scelti: (1.165e-01 , 1.669e-03)  marginal y 2.5075e+90
# 	acceptance rate = 0.4000  for subject 6
# 	phi scelti: (1.290e-01 , 7.264e-04)  marginal y 2.3306e+63
#  final_simplex: (array([[1.20805295e-01, 1.64738714e-03, 1.72415150e-02, 9.71752082e-04,
#         1.97531666e-01, 4.06081664e-05],
#        [1.20814568e-01, 1.64834736e-03, 1.72391000e-02, 9.72069918e-04,
#         1.97622302e-01, 4.05833936e-05],
#        [1.20803383e-01, 1.64833735e-03, 1.72465400e-02, 9.71872246e-04,
#         1.97520350e-01, 4.05968207e-05],
#        [1.20878300e-01, 1.64850836e-03, 1.72302305e-02, 9.70882944e-04,
#         1.97584764e-01, 4.05707727e-05],
#        [1.20863617e-01, 1.64893452e-03, 1.72260830e-02, 9.71708038e-04,
#         1.97485241e-01, 4.05942692e-05],
#        [1.20876545e-01, 1.64913020e-03, 1.72128351e-02, 9.70230762e-04,
#         1.97587199e-01, 4.06061177e-05],
#        [1.20802103e-01, 1.65002559e-03, 1.72130978e-02, 9.69792106e-04,
#         1.97575978e-01, 4.05972943e-05]]), array([-1618.13488336, -1618.13487586, -1618.13487446, -1618.13484839,
#        -1618.13484248, -1618.13481615, -1618.13479601]))
#            fun: -1618.134883364502
#        message: 'Optimization terminated successfully.'
#           nfev: 128
#            nit: 70
#         status: 0
#        success: True
#              x: array([1.20805295e-01, 1.64738714e-03, 1.72415150e-02, 9.71752082e-04,
#        1.97531666e-01, 4.06081664e-05])
# ### ottimizazione iterazione :  26
# 	acceptance rate = 0.3100  for subject 1
# 	phi scelti: (1.336e-01 , 8.655e-04)  marginal y 7.4266e+76
# 	acceptance rate = 0.2600  for subject 2
# 	phi scelti: (1.140e-01 , 1.781e-03)  marginal y 2.6273e+67
# 	acceptance rate = 0.3900  for subject 3
# 	phi scelti: (1.356e-01 , 4.363e-04)  marginal y 1.1819e+84
# 	acceptance rate = 0.3167  for subject 4
# 	phi scelti: (1.214e-01 , 1.123e-03)  marginal y 5.6250e+61
# 	acceptance rate = 0.1833  for subject 5
# 	phi scelti: (1.193e-01 , 1.683e-03)  marginal y 4.3941e+90
# 	acceptance rate = 0.4767  for subject 6
# 	phi scelti: (1.171e-01 , 1.192e-03)  marginal y 1.7740e+63
#  final_simplex: (array([[1.20798783e-01, 1.64206988e-03, 1.72563468e-02, 9.69800177e-04,
#         1.97586444e-01, 4.05845469e-05],
#        [1.20838570e-01, 1.64324941e-03, 1.72169740e-02, 9.70460868e-04,
#         1.97511136e-01, 4.05799113e-05],
#        [1.20868712e-01, 1.64378587e-03, 1.72429356e-02, 9.68859638e-04,
#         1.97623643e-01, 4.05857118e-05],
#        [1.20829075e-01, 1.64409532e-03, 1.72405251e-02, 9.68721192e-04,
#         1.97505743e-01, 4.05760558e-05],
#        [1.20793995e-01, 1.64452871e-03, 1.72375368e-02, 9.68914523e-04,
#         1.97542779e-01, 4.05765343e-05],
#        [1.20849923e-01, 1.64430139e-03, 1.72317993e-02, 9.70463973e-04,
#         1.97518902e-01, 4.05593347e-05],
#        [1.20855174e-01, 1.64162909e-03, 1.72373688e-02, 9.68176224e-04,
#         1.97637618e-01, 4.05845359e-05]]), array([-1618.13489736, -1618.13489619, -1618.13489562, -1618.134886  ,
#        -1618.13488109, -1618.13487387, -1618.13484753]))
#            fun: -1618.1348973579275
#        message: 'Optimization terminated successfully.'
#           nfev: 199
#            nit: 122
#         status: 0
#        success: True
#              x: array([1.20798783e-01, 1.64206988e-03, 1.72563468e-02, 9.69800177e-04,
#        1.97586444e-01, 4.05845469e-05])
# ### ottimizazione iterazione :  27
# 	acceptance rate = 0.3000  for subject 1
# 	phi scelti: (1.108e-01 , 1.404e-03)  marginal y 9.3201e+76
# 	acceptance rate = 0.2367  for subject 2
# 	phi scelti: (1.123e-01 , 1.944e-03)  marginal y 1.6913e+67
# 	acceptance rate = 0.4367  for subject 3
# 	phi scelti: (1.246e-01 , 4.487e-04)  marginal y 9.0135e+83
# 	acceptance rate = 0.4100  for subject 4
# 	phi scelti: (1.281e-01 , 1.045e-03)  marginal y 1.6003e+62
# 	acceptance rate = 0.2200  for subject 5
# 	phi scelti: (1.092e-01 , 2.006e-03)  marginal y 2.1743e+90
# 	acceptance rate = 0.4533  for subject 6
# 	phi scelti: (1.172e-01 , 1.098e-03)  marginal y 2.1136e+63
#  final_simplex: (array([[1.20871134e-01, 1.64538280e-03, 1.72248978e-02, 9.69987715e-04,
#         1.97649585e-01, 4.05951839e-05],
#        [1.20864858e-01, 1.64535843e-03, 1.72201006e-02, 9.69300540e-04,
#         1.97553316e-01, 4.05913529e-05],
#        [1.20864298e-01, 1.64535879e-03, 1.72168912e-02, 9.70028314e-04,
#         1.97573293e-01, 4.05765306e-05],
#        [1.20879367e-01, 1.64595998e-03, 1.72243343e-02, 9.70119141e-04,
#         1.97611321e-01, 4.06015690e-05],
#        [1.20867444e-01, 1.64476626e-03, 1.72173059e-02, 9.69269858e-04,
#         1.97615311e-01, 4.05881804e-05],
#        [1.20880403e-01, 1.64481181e-03, 1.72220644e-02, 9.69284559e-04,
#         1.97551845e-01, 4.05950137e-05],
#        [1.20883816e-01, 1.64629550e-03, 1.72255614e-02, 9.69488426e-04,
#         1.97586502e-01, 4.05887214e-05]]), array([-1618.13489624, -1618.13489511, -1618.13489357, -1618.13489128,
#        -1618.13488784, -1618.13488678, -1618.13488465]))
#            fun: -1618.1348962361562
#        message: 'Optimization terminated successfully.'
#           nfev: 150
#            nit: 84
#         status: 0
#        success: True
#              x: array([1.20871134e-01, 1.64538280e-03, 1.72248978e-02, 9.69987715e-04,
#        1.97649585e-01, 4.05951839e-05])
# ### ottimizazione iterazione :  28
# 	acceptance rate = 0.2167  for subject 1
# 	phi scelti: (1.230e-01 , 1.461e-03)  marginal y 2.2581e+77
# 	acceptance rate = 0.3500  for subject 2
# 	phi scelti: (1.357e-01 , 1.095e-03)  marginal y 1.1156e+67
# 	acceptance rate = 0.3667  for subject 3
# 	phi scelti: (1.429e-01 , 3.330e-04)  marginal y 1.4200e+84
# 	acceptance rate = 0.3033  for subject 4
# 	phi scelti: (1.314e-01 , 9.872e-04)  marginal y 6.8482e+61
# 	acceptance rate = 0.1267  for subject 5
# 	phi scelti: (1.208e-01 , 1.876e-03)  marginal y 1.1143e+90
# 	acceptance rate = 0.3767  for subject 6
# 	phi scelti: (1.574e-01 , 4.522e-04)  marginal y 1.3147e+63
#  final_simplex: (array([[1.20842096e-01, 1.64460594e-03, 1.72373593e-02, 9.71324398e-04,
#         1.97669594e-01, 4.06048083e-05],
#        [1.20832131e-01, 1.64533117e-03, 1.72086269e-02, 9.71027331e-04,
#         1.97582381e-01, 4.05915472e-05],
#        [1.20845984e-01, 1.64632814e-03, 1.72330547e-02, 9.69046287e-04,
#         1.97643892e-01, 4.05969230e-05],
#        [1.20833961e-01, 1.64136720e-03, 1.72755578e-02, 9.70460316e-04,
#         1.97650978e-01, 4.05828559e-05],
#        [1.20858394e-01, 1.64542683e-03, 1.72736926e-02, 9.71548704e-04,
#         1.97719300e-01, 4.05899029e-05],
#        [1.20900475e-01, 1.64287250e-03, 1.72428276e-02, 9.69509822e-04,
#         1.97657737e-01, 4.05840836e-05],
#        [1.20851529e-01, 1.64299451e-03, 1.72162025e-02, 9.71439884e-04,
#         1.97716852e-01, 4.05850233e-05]]), array([-1618.13490863, -1618.13490329, -1618.13489067, -1618.13488235,
#        -1618.13488087, -1618.1348618 , -1618.13485974]))
#            fun: -1618.1349086349285
#        message: 'Optimization terminated successfully.'
#           nfev: 239
#            nit: 148
#         status: 0
#        success: True
#              x: array([1.20842096e-01, 1.64460594e-03, 1.72373593e-02, 9.71324398e-04,
#        1.97669594e-01, 4.06048083e-05])
# ### ottimizazione iterazione :  29
# 	acceptance rate = 0.2933  for subject 1
# 	phi scelti: (1.151e-01 , 1.242e-03)  marginal y 1.1846e+77
# 	acceptance rate = 0.2267  for subject 2
# 	phi scelti: (1.329e-01 , 1.081e-03)  marginal y 3.7494e+66
# 	acceptance rate = 0.4267  for subject 3
# 	phi scelti: (1.376e-01 , 3.438e-04)  marginal y 8.0200e+83
# 	acceptance rate = 0.3233  for subject 4
# 	phi scelti: (1.408e-01 , 7.709e-04)  marginal y 6.1011e+61
# 	acceptance rate = 0.1667  for subject 5
# 	phi scelti: (1.194e-01 , 1.637e-03)  marginal y 2.0669e+90
# 	acceptance rate = 0.3767  for subject 6
# 	phi scelti: (1.377e-01 , 7.653e-04)  marginal y 1.3565e+63
#  final_simplex: (array([[1.20810873e-01, 1.64501341e-03, 1.72567630e-02, 9.69203425e-04,
#         1.97506704e-01, 4.05929786e-05],
#        [1.20789120e-01, 1.64201802e-03, 1.72612214e-02, 9.69763776e-04,
#         1.97549641e-01, 4.05858790e-05],
#        [1.20832791e-01, 1.64282907e-03, 1.72749430e-02, 9.68599982e-04,
#         1.97583343e-01, 4.06081916e-05],
#        [1.20829647e-01, 1.64464952e-03, 1.72849455e-02, 9.68273433e-04,
#         1.97582795e-01, 4.05811991e-05],
#        [1.20843162e-01, 1.64303622e-03, 1.72747687e-02, 9.69283750e-04,
#         1.97438028e-01, 4.05928274e-05],
#        [1.20892210e-01, 1.64335130e-03, 1.72617107e-02, 9.69537135e-04,
#         1.97605485e-01, 4.05635789e-05],
#        [1.20789177e-01, 1.64398903e-03, 1.72947002e-02, 9.68962880e-04,
#         1.97602041e-01, 4.06027214e-05]]), array([-1618.13490619, -1618.13488595, -1618.1348721 , -1618.13487154,
#        -1618.13486674, -1618.13485389, -1618.13484938]))
#            fun: -1618.1349061884112
#        message: 'Optimization terminated successfully.'
#           nfev: 113
#            nit: 60
#         status: 0
#        success: True
#              x: array([1.20810873e-01, 1.64501341e-03, 1.72567630e-02, 9.69203425e-04,
#        1.97506704e-01, 4.05929786e-05])
# tempo esecuzione : 8106.52015

# %%
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2,figsize=(15,10))
ax1.plot(-SAEM.log_lik_history, label= "log loss - iterations"); 
ax2.plot(SAEM.theta_history[0,:], SAEM.theta_history[1,:], label= "kappa - alpha")
ax3.plot(SAEM.theta_history[0,:], label= "alpha - iteration", color= "green");
ax4.plot(SAEM.theta_history[1,:], label= "kappa - iteration", color= "orange")
ax1.legend();ax2.legend(); ax3.legend(); ax4.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
def x_fun_espl(t, alpha, kappa, Y_0):
    y = kappa * np.exp( np.log(Y_0/kappa) *  np.exp(- alpha* t))
    return y

# %%
plt.figure(figsize=(10,10))
tempo = np.linspace(0.0, 25, 25000)
for s_ in range(1,7):
    SAEM.select_subj(s_)
    c_r = tuple(np.random.rand(1,3).tolist()[0])
    plt.plot(SAEM.timei, SAEM.yobsi, "*", color= c_r)
    x_hati = x_fun_espl(tempo, SAEM.PhiALL[SAEM.iterazione,s_ - 1, 0], SAEM.PhiALL[SAEM.iterazione,s_ -1, 1], 1e-7)  
    plt.plot(tempo, x_hati, "g-", label = "soggetto "+str(s_), color= c_r) 
    
x_hat_medio = x_fun_espl(tempo,  SAEM.theta_choose[0], SAEM.theta_choose[1], 1e-7)  
plt.plot(tempo, x_hat_medio, label = "medio popolazione", color="black")
plt.legend()

# %%
s_=6
SAEM.select_subj(s_)
c_r = tuple(np.random.rand(1,3).tolist()[0])
plt.plot(SAEM.timei, SAEM.yobsi, "*", color= c_r)
tempo = np.linspace(0.0, 25, 25000)
x_hat_medio = x_fun_espl(tempo,  SAEM.theta_choose[0], SAEM.theta_choose[1], 1e-7)  
x_hati = x_fun_espl(tempo, SAEM.PhiALL[SAEM.iterazione,s_ - 1, 0], SAEM.PhiALL[SAEM.iterazione,s_ -1, 1], 1e-7)  
plt.plot(tempo, x_hati, "g-", label = "ultimi phii PMCMC", color= c_r)
