# %%
from SAEM import Stochasti_Approximation_Expectation_Maximization
from time import time

# %%
start = time()
# self.PARMIN = [0.01, 1e-6, 0.0001, 1e-5, 0.0001, 1e-5] ; self.PARMAX = [1, 1e-1, 0.05, 1e-1, 1, 1e-3]
theta = [0.3, 0.009, 0.2, 0.3, 0.3, 0.0001]   # [0.27, 0.0005, 0.04, 0.0035, 0.18, 0.0001]
SAEM = Stochasti_Approximation_Expectation_Maximization()
#SAEM.inizializza(theta)
SAEM.run(theta)
print("tempo esecuzione : %.5f "% (time()-start))
# Out:
# ### ottimizazione iterazione :  0
# 	acceptance rate = 0.3200  for subject 1
# 	phi scelti: (1.125e-01 , 8.903e-03)  marginal y 3.5686e+72
# 	acceptance rate = 0.5300  for subject 2
# 	phi scelti: (1.375e-01 , 4.334e-03)  marginal y 2.0531e+63
# 	acceptance rate = 0.0700  for subject 3
# 	phi scelti: (2.459e-01 , 8.833e-03)  marginal y 5.0791e+65
# 	acceptance rate = 0.0300  for subject 4
# 	phi scelti: (2.987e-01 , 8.403e-03)  marginal y 5.2487e+47
# 	acceptance rate = 0.3000  for subject 5
# 	phi scelti: (1.262e-01 , 3.924e-03)  marginal y 4.8718e+84
# 	acceptance rate = 0.0600  for subject 6
# 	phi scelti: (3.117e-01 , 9.577e-03)  marginal y 3.3486e+48
#  final_simplex: (array([[1.15984189e-02, 7.40787118e-05, 3.46525805e-01, 7.65282507e-03,
#         4.99999863e-01, 4.08378519e-04],
#        [1.16387265e-02, 7.42516038e-05, 3.46531147e-01, 7.65120520e-03,
#         4.99999865e-01, 4.08366208e-04],
#        [1.16393717e-02, 7.43306066e-05, 3.46532915e-01, 7.64804077e-03,
#         4.99999821e-01, 4.08364348e-04],
#        [1.16894613e-02, 7.38746831e-05, 3.46532216e-01, 7.66326255e-03,
#         4.99998984e-01, 4.08363661e-04],
#        [1.16783369e-02, 7.40967284e-05, 3.46540068e-01, 7.64800448e-03,
#         4.99998057e-01, 4.08361131e-04],
#        [1.16394648e-02, 7.41930417e-05, 3.46539069e-01, 7.64107015e-03,
#         4.99998086e-01, 4.08367255e-04],
#        [1.16930826e-02, 7.38929259e-05, 3.46539204e-01, 7.65411634e-03,
#         4.99997741e-01, 4.08362449e-04]]), array([214.52030279, 214.52030677, 214.52030855, 214.52036587,
#        214.52038702, 214.52038939, 214.52040246]))
#            fun: 214.52030279476992
#        message: 'Optimization terminated successfully.'
#           nfev: 696
#            nit: 409
#         status: 0
#        success: True
#              x: array([1.15984189e-02, 7.40787118e-05, 3.46525805e-01, 7.65282507e-03,
#        4.99999863e-01, 4.08378519e-04])
# ### ottimizazione iterazione :  1
# 	acceptance rate = 0.8900  for subject 1
# 	phi scelti: (9.053e-02 , 8.700e-03)  marginal y 9.3878e+64
# 	acceptance rate = 0.8900  for subject 2
# 	phi scelti: (1.082e-01 , 3.935e-03)  marginal y 3.8102e+56
# 	acceptance rate = 0.8700  for subject 3
# 	phi scelti: (5.635e-02 , 7.446e-03)  marginal y 7.8251e+69
# 	acceptance rate = 0.7300  for subject 4
# 	phi scelti: (1.043e-01 , 4.313e-03)  marginal y 1.3946e+52
# 	acceptance rate = 0.6800  for subject 5
# 	phi scelti: (1.050e-01 , 3.880e-03)  marginal y 8.9976e+76
# 	acceptance rate = 0.9000  for subject 6
# 	phi scelti: (1.174e-01 , 5.006e-03)  marginal y 3.1442e+52
#  final_simplex: (array([[1.00000675e-02, 2.42899748e-04, 9.52515329e-02, 9.31152443e-03,
#         4.98604242e-01, 1.86476342e-04],
#        [1.00002417e-02, 2.42875286e-04, 9.53004123e-02, 9.31120162e-03,
#         4.98604430e-01, 1.86495500e-04],
#        [1.00003696e-02, 2.42863257e-04, 9.53010250e-02, 9.31089995e-03,
#         4.98604453e-01, 1.86522925e-04],
#        [1.00005900e-02, 2.42867560e-04, 9.52072027e-02, 9.31047363e-03,
#         4.98604153e-01, 1.86583219e-04],
#        [1.00007437e-02, 2.42863118e-04, 9.52389220e-02, 9.31062991e-03,
#         4.98604254e-01, 1.86566555e-04],
#        [1.00009352e-02, 2.42883435e-04, 9.52154413e-02, 9.31116969e-03,
#         4.98604141e-01, 1.86531579e-04],
#        [1.00010142e-02, 2.42870432e-04, 9.53100170e-02, 9.31147178e-03,
#         4.98604450e-01, 1.86487449e-04]]), array([2695.21331959, 2695.21333614, 2695.21334315, 2695.21336715,
#        2695.21337468, 2695.2133804 , 2695.21339393]))
#            fun: 2695.2133195864544
#        message: 'Optimization terminated successfully.'
#           nfev: 874
#            nit: 537
#         status: 0
#        success: True
#              x: array([1.00000675e-02, 2.42899748e-04, 9.52515329e-02, 9.31152443e-03,
#        4.98604242e-01, 1.86476342e-04])
# ### ottimizazione iterazione :  2
# 	acceptance rate = 0.5100  for subject 1
# 	phi scelti: (1.070e-01 , 5.050e-03)  marginal y 5.8595e+68
# 	acceptance rate = 0.7800  for subject 2
# 	phi scelti: (1.099e-01 , 2.445e-03)  marginal y 5.3228e+59
# 	acceptance rate = 0.9000  for subject 3
# 	phi scelti: (6.492e-02 , 9.075e-03)  marginal y 2.2079e+74
# 	acceptance rate = 0.8300  for subject 4
# 	phi scelti: (9.572e-02 , 4.288e-03)  marginal y 5.1885e+54
# 	acceptance rate = 0.2900  for subject 5
# 	phi scelti: (1.120e-01 , 3.541e-03)  marginal y 5.2669e+80
# 	acceptance rate = 0.8900  for subject 6
# 	phi scelti: (1.017e-01 , 4.768e-03)  marginal y 1.1009e+56
#  final_simplex: (array([[2.39438834e-02, 1.00010025e-05, 7.76482259e-02, 5.31475383e-03,
#         4.99977434e-01, 1.23178593e-04],
#        [2.39436902e-02, 1.00039242e-05, 7.76600111e-02, 5.31893561e-03,
#         4.99977490e-01, 1.23191054e-04],
#        [2.39472025e-02, 1.00046648e-05, 7.77140993e-02, 5.31701145e-03,
#         4.99977466e-01, 1.23168414e-04],
#        [2.39418128e-02, 1.00128288e-05, 7.75886374e-02, 5.31675956e-03,
#         4.99977413e-01, 1.23177978e-04],
#        [2.39423345e-02, 1.00120149e-05, 7.76520456e-02, 5.31585651e-03,
#         4.99977468e-01, 1.23191716e-04],
#        [2.39388933e-02, 1.00030917e-05, 7.76051894e-02, 5.32232833e-03,
#         4.99977553e-01, 1.23229530e-04],
#        [2.39382619e-02, 1.00115014e-05, 7.75870918e-02, 5.31301902e-03,
#         4.99977442e-01, 1.23206978e-04]]), array([1840.00693824, 1840.00695413, 1840.00695974, 1840.006971  ,
#        1840.00697511, 1840.00697639, 1840.00697871]))
#            fun: 1840.0069382396414
#        message: 'Optimization terminated successfully.'
#           nfev: 903
#            nit: 565
#         status: 0
#        success: True
#              x: array([2.39438834e-02, 1.00010025e-05, 7.76482259e-02, 5.31475383e-03,
#        4.99977434e-01, 1.23178593e-04])
# ### ottimizazione iterazione :  3
# 	acceptance rate = 0.3600  for subject 1
# 	phi scelti: (1.519e-01 , 4.726e-03)  marginal y 2.2485e+70
# 	acceptance rate = 0.4400  for subject 2
# 	phi scelti: (1.381e-01 , 5.091e-03)  marginal y 4.1956e+61
# 	acceptance rate = 0.6900  for subject 3
# 	phi scelti: (8.066e-02 , 3.931e-03)  marginal y 3.7134e+76
# 	acceptance rate = 0.5300  for subject 4
# 	phi scelti: (1.220e-01 , 6.023e-03)  marginal y 1.3728e+56
# 	acceptance rate = 0.2500  for subject 5
# 	phi scelti: (1.231e-01 , 3.650e-03)  marginal y 5.2131e+81
# 	acceptance rate = 0.7400  for subject 6
# 	phi scelti: (2.170e-01 , 5.197e-04)  marginal y 7.3217e+57
#  final_simplex: (array([[1.38283106e-01, 3.15055001e-05, 4.06020820e-02, 4.05220889e-03,
#         4.99999987e-01, 1.29678793e-04],
#        [1.38205626e-01, 3.14833925e-05, 4.06166096e-02, 4.05345500e-03,
#         4.99999968e-01, 1.29568846e-04],
#        [1.38314132e-01, 3.15067171e-05, 4.06649541e-02, 4.05131469e-03,
#         4.99999840e-01, 1.29601505e-04],
#        [1.38289451e-01, 3.15039336e-05, 4.06383818e-02, 4.05177341e-03,
#         4.99999866e-01, 1.29617406e-04],
#        [1.38220201e-01, 3.14826791e-05, 4.06146393e-02, 4.05379781e-03,
#         4.99999809e-01, 1.29547272e-04],
#        [1.38281835e-01, 3.14993503e-05, 4.06293312e-02, 4.05243904e-03,
#         4.99999762e-01, 1.29605340e-04],
#        [1.38326850e-01, 3.15098541e-05, 4.05857047e-02, 4.05234542e-03,
#         4.99999881e-01, 1.29637954e-04]]), array([1658.82464725, 1658.82465437, 1658.8246779 , 1658.82470293,
#        1658.82470511, 1658.8247083 , 1658.82471008]))
#            fun: 1658.8246472549456
#        message: 'Optimization terminated successfully.'
#           nfev: 410
#            nit: 246
#         status: 0
#        success: True
#              x: array([1.38283106e-01, 3.15055001e-05, 4.06020820e-02, 4.05220889e-03,
#        4.99999987e-01, 1.29678793e-04])
# ### ottimizazione iterazione :  4
# 	acceptance rate = 0.5300  for subject 1
# 	phi scelti: (1.657e-01 , 1.937e-03)  marginal y 1.6612e+70
# 	acceptance rate = 0.4100  for subject 2
# 	phi scelti: (1.381e-01 , 5.091e-03)  marginal y 4.0743e+61
# 	acceptance rate = 0.6300  for subject 3
# 	phi scelti: (1.027e-01 , 2.242e-03)  marginal y 1.7490e+76
# 	acceptance rate = 0.3100  for subject 4
# 	phi scelti: (1.082e-01 , 3.672e-03)  marginal y 1.7952e+56
# 	acceptance rate = 0.2100  for subject 5
# 	phi scelti: (1.402e-01 , 3.147e-03)  marginal y 6.0413e+81
# 	acceptance rate = 0.7900  for subject 6
# 	phi scelti: (2.170e-01 , 5.197e-04)  marginal y 5.0001e+57
#  final_simplex: (array([[1.45440521e-01, 3.73574911e-05, 3.83279628e-02, 3.09358749e-03,
#         4.99999997e-01, 1.39096508e-04],
#        [1.45410295e-01, 3.73651461e-05, 3.83598818e-02, 3.09052416e-03,
#         4.99999992e-01, 1.39128529e-04],
#        [1.45422123e-01, 3.73554970e-05, 3.83638355e-02, 3.09112551e-03,
#         4.99999999e-01, 1.39165089e-04],
#        [1.45415224e-01, 3.73299237e-05, 3.84140068e-02, 3.09138513e-03,
#         4.99999982e-01, 1.39069968e-04],
#        [1.45373201e-01, 3.73750759e-05, 3.83879978e-02, 3.08740600e-03,
#         4.99999998e-01, 1.39202425e-04],
#        [1.45447628e-01, 3.73350305e-05, 3.83745828e-02, 3.09258816e-03,
#         4.99999982e-01, 1.39097366e-04],
#        [1.45454178e-01, 3.73264057e-05, 3.83484659e-02, 3.09701621e-03,
#         4.99999981e-01, 1.39007272e-04]]), array([887.86212139, 887.86212671, 887.86218486, 887.86218604,
#        887.86219885, 887.86221229, 887.86221665]))
#            fun: 887.8621213933358
#        message: 'Optimization terminated successfully.'
#           nfev: 270
#            nit: 161
#         status: 0
#        success: True
#              x: array([1.45440521e-01, 3.73574911e-05, 3.83279628e-02, 3.09358749e-03,
#        4.99999997e-01, 1.39096508e-04])
# ### ottimizazione iterazione :  5
# 	acceptance rate = 0.5300  for subject 1
# 	phi scelti: (1.458e-01 , 2.848e-03)  marginal y 1.3153e+70
# 	acceptance rate = 0.5200  for subject 2
# 	phi scelti: (1.528e-01 , 1.886e-03)  marginal y 1.8550e+61
# 	acceptance rate = 0.7300  for subject 3
# 	phi scelti: (9.208e-02 , 2.343e-03)  marginal y 1.3372e+76
# 	acceptance rate = 0.4900  for subject 4
# 	phi scelti: (1.141e-01 , 3.231e-03)  marginal y 1.4657e+56
# 	acceptance rate = 0.2400  for subject 5
# 	phi scelti: (1.678e-01 , 3.496e-03)  marginal y 2.8946e+81
# 	acceptance rate = 0.8100  for subject 6
# 	phi scelti: (2.197e-01 , 2.750e-04)  marginal y 1.6439e+57
#  final_simplex: (array([[1.50003702e-01, 2.88876703e-05, 4.13288520e-02, 2.73972913e-03,
#         4.99999930e-01, 2.13701152e-04],
#        [1.49964379e-01, 2.89253948e-05, 4.12740104e-02, 2.74180409e-03,
#         4.99999940e-01, 2.13661919e-04],
#        [1.50055902e-01, 2.89156561e-05, 4.12548474e-02, 2.74005442e-03,
#         4.99999929e-01, 2.13795980e-04],
#        [1.50053129e-01, 2.88944049e-05, 4.13087227e-02, 2.73925379e-03,
#         4.99999906e-01, 2.13723868e-04],
#        [1.49946683e-01, 2.89013345e-05, 4.13009344e-02, 2.74123268e-03,
#         4.99999945e-01, 2.13725557e-04],
#        [1.50045067e-01, 2.88990185e-05, 4.12998286e-02, 2.73955563e-03,
#         4.99999885e-01, 2.13730034e-04],
#        [1.49987284e-01, 2.89234329e-05, 4.12610638e-02, 2.74141300e-03,
#         4.99999901e-01, 2.13725949e-04]]), array([1953.19047037, 1953.19047794, 1953.19047813, 1953.19048556,
#        1953.19048769, 1953.19050496, 1953.1905055 ]))
#            fun: 1953.19047037447
#        message: 'Optimization terminated successfully.'
#           nfev: 396
#            nit: 238
#         status: 0
#        success: True
#              x: array([1.50003702e-01, 2.88876703e-05, 4.13288520e-02, 2.73972913e-03,
#        4.99999930e-01, 2.13701152e-04])
# ### ottimizazione iterazione :  6
# 	acceptance rate = 0.5900  for subject 1
# 	phi scelti: (1.304e-01 , 2.901e-03)  marginal y 1.9684e+68
# 	acceptance rate = 0.6500  for subject 2
# 	phi scelti: (1.528e-01 , 1.886e-03)  marginal y 3.7990e+59
# 	acceptance rate = 0.8800  for subject 3
# 	phi scelti: (1.052e-01 , 2.050e-03)  marginal y 7.0865e+73
# 	acceptance rate = 0.6800  for subject 4
# 	phi scelti: (1.738e-01 , 1.177e-03)  marginal y 4.2972e+54
# 	acceptance rate = 0.3800  for subject 5
# 	phi scelti: (2.052e-01 , 7.248e-04)  marginal y 1.3506e+80
# 	acceptance rate = 0.8900  for subject 6
# 	phi scelti: (2.197e-01 , 2.750e-04)  marginal y 4.0331e+55
#  final_simplex: (array([[1.00005486e-02, 1.00010577e-05, 1.44165894e-01, 1.10651973e-02,
#         4.99997552e-01, 3.97273936e-04],
#        [1.00000224e-02, 1.00010779e-05, 1.44251892e-01, 1.10741244e-02,
#         4.99977635e-01, 3.97260342e-04],
#        [1.00002326e-02, 1.00010475e-05, 1.44132447e-01, 1.10611837e-02,
#         4.99966939e-01, 3.97307905e-04],
#        [1.00005796e-02, 1.00010529e-05, 1.44163041e-01, 1.10645504e-02,
#         4.99973180e-01, 3.97292351e-04],
#        [1.00003308e-02, 1.00010783e-05, 1.44262480e-01, 1.10750667e-02,
#         4.99963910e-01, 3.97265805e-04],
#        [1.00011849e-02, 1.00010542e-05, 1.44147903e-01, 1.10632572e-02,
#         4.99996563e-01, 3.97278925e-04],
#        [1.00008173e-02, 1.00010568e-05, 1.44177233e-01, 1.10659022e-02,
#         4.99961277e-01, 3.97295294e-04]]), array([215.85513938, 215.85514247, 215.85516374, 215.8551753 ,
#        215.85519134, 215.85520291, 215.85522341]))
#            fun: 215.85513938159573
#        message: 'Optimization terminated successfully.'
#           nfev: 647
#            nit: 393
#         status: 0
#        success: True
#              x: array([1.00005486e-02, 1.00010577e-05, 1.44165894e-01, 1.10651973e-02,
#        4.99997552e-01, 3.97273936e-04])
# ### ottimizazione iterazione :  7
# 	acceptance rate = 0.9100  for subject 1
# 	phi scelti: (1.263e-01 , 1.792e-03)  marginal y 1.7731e+65
# 	acceptance rate = 0.8800  for subject 2
# 	phi scelti: (1.694e-01 , 1.297e-03)  marginal y 5.6115e+56
# 	acceptance rate = 0.9100  for subject 3
# 	phi scelti: (7.334e-02 , 3.800e-03)  marginal y 1.3030e+70
# 	acceptance rate = 0.9300  for subject 4
# 	phi scelti: (1.879e-01 , 6.653e-04)  marginal y 1.9776e+52
# 	acceptance rate = 0.8000  for subject 5
# 	phi scelti: (1.734e-01 , 8.618e-04)  marginal y 2.2596e+77
# 	acceptance rate = 0.9600  for subject 6
# 	phi scelti: (2.346e-01 , 2.237e-04)  marginal y 4.4612e+52
#  final_simplex: (array([[2.05299426e-01, 7.12503275e-05, 8.28997370e-02, 7.60913159e-03,
#         4.98359793e-01, 4.44488798e-04],
#        [2.05212183e-01, 7.12252257e-05, 8.28933832e-02, 7.61230444e-03,
#         4.98360399e-01, 4.44519443e-04],
#        [2.05264291e-01, 7.12377010e-05, 8.29347910e-02, 7.60691419e-03,
#         4.98360204e-01, 4.44560599e-04],
#        [2.05353699e-01, 7.12628102e-05, 8.29046308e-02, 7.61462524e-03,
#         4.98359501e-01, 4.44477717e-04],
#        [2.05227104e-01, 7.12231098e-05, 8.29612913e-02, 7.61291854e-03,
#         4.98360572e-01, 4.44494681e-04],
#        [2.05248419e-01, 7.12330657e-05, 8.29033718e-02, 7.61325771e-03,
#         4.98360273e-01, 4.44632316e-04],
#        [2.05210446e-01, 7.12250903e-05, 8.28754526e-02, 7.61328016e-03,
#         4.98360420e-01, 4.44631860e-04]]), array([207.2451922 , 207.24519278, 207.24519408, 207.24519487,
#        207.24519572, 207.24519588, 207.24519769]))
#            fun: 207.24519219846314
#        message: 'Optimization terminated successfully.'
#           nfev: 996
#            nit: 629
#         status: 0
#        success: True
#              x: array([2.05299426e-01, 7.12503275e-05, 8.28997370e-02, 7.60913159e-03,
#        4.98359793e-01, 4.44488798e-04])
# ### ottimizazione iterazione :  8
# 	acceptance rate = 0.8800  for subject 1
# 	phi scelti: (1.167e-01 , 2.061e-03)  marginal y 4.1973e+64
# 	acceptance rate = 0.9100  for subject 2
# 	phi scelti: (1.533e-01 , 1.367e-03)  marginal y 1.3771e+56
# 	acceptance rate = 0.9100  for subject 3
# 	phi scelti: (6.702e-02 , 3.939e-03)  marginal y 2.4307e+69
# 	acceptance rate = 0.9300  for subject 4
# 	phi scelti: (1.762e-01 , 6.992e-04)  marginal y 6.9049e+51
# 	acceptance rate = 0.7700  for subject 5
# 	phi scelti: (1.867e-01 , 8.338e-04)  marginal y 5.7965e+76
# 	acceptance rate = 0.9700  for subject 6
# 	phi scelti: (2.486e-01 , 1.813e-04)  marginal y 1.2422e+52
#  final_simplex: (array([[2.05222709e-01, 7.59373809e-05, 8.32451684e-02, 7.57187978e-03,
#         4.99999995e-01, 4.44110762e-04],
#        [2.05183183e-01, 7.59443375e-05, 8.32452652e-02, 7.56981425e-03,
#         4.99999789e-01, 4.44189899e-04],
#        [2.05318426e-01, 7.59653412e-05, 8.32431905e-02, 7.57026210e-03,
#         4.99999938e-01, 4.44029166e-04],
#        [2.05200574e-01, 7.59352639e-05, 8.32455058e-02, 7.57210023e-03,
#         4.99999782e-01, 4.44107470e-04],
#        [2.05136507e-01, 7.58675383e-05, 8.32482728e-02, 7.57885712e-03,
#         4.99999994e-01, 4.44142576e-04],
#        [2.05257802e-01, 7.59355380e-05, 8.32449005e-02, 7.57329246e-03,
#         4.99999960e-01, 4.44035929e-04],
#        [2.05175771e-01, 7.59513620e-05, 8.32453910e-02, 7.57003349e-03,
#         4.99999752e-01, 4.44123899e-04]]), array([207.16804084, 207.16804218, 207.16805381, 207.16805518,
#        207.16805577, 207.16805722, 207.16805838]))
#            fun: 207.16804084110288
#        message: 'Optimization terminated successfully.'
#           nfev: 252
#            nit: 137
#         status: 0
#        success: True
#              x: array([2.05222709e-01, 7.59373809e-05, 8.32451684e-02, 7.57187978e-03,
#        4.99999995e-01, 4.44110762e-04])
# ### ottimizazione iterazione :  9
# 	acceptance rate = 0.8500  for subject 1
# 	phi scelti: (1.297e-01 , 2.390e-03)  marginal y 4.1868e+64
# 	acceptance rate = 0.9000  for subject 2
# 	phi scelti: (1.849e-01 , 1.129e-03)  marginal y 1.4696e+56
# 	acceptance rate = 0.9700  for subject 3
# 	phi scelti: (8.566e-02 , 4.321e-03)  marginal y 2.6169e+69
# 	acceptance rate = 0.8800  for subject 4
# 	phi scelti: (1.985e-01 , 6.115e-04)  marginal y 7.2789e+51
# 	acceptance rate = 0.8000  for subject 5
# 	phi scelti: (2.279e-01 , 7.414e-04)  marginal y 6.6834e+76
# 	acceptance rate = 0.9400  for subject 6
# 	phi scelti: (2.957e-01 , 1.500e-04)  marginal y 1.3031e+52
#  final_simplex: (array([[2.03267794e-01, 8.17791332e-05, 8.51021696e-02, 7.37370391e-03,
#         4.99999988e-01, 4.45353617e-04],
#        [2.03277302e-01, 8.16144808e-05, 8.51335130e-02, 7.37932073e-03,
#         4.99999782e-01, 4.45431100e-04],
#        [2.03354508e-01, 8.17762127e-05, 8.51306235e-02, 7.37147187e-03,
#         4.99999795e-01, 4.45270827e-04],
#        [2.03360852e-01, 8.16705186e-05, 8.51343256e-02, 7.37536278e-03,
#         4.99999615e-01, 4.45413476e-04],
#        [2.03209245e-01, 8.18946931e-05, 8.50608575e-02, 7.37105306e-03,
#         4.99999433e-01, 4.45363158e-04],
#        [2.03267451e-01, 8.15916853e-05, 8.51471858e-02, 7.38027035e-03,
#         4.99999346e-01, 4.45381222e-04],
#        [2.03307116e-01, 8.16624343e-05, 8.51727206e-02, 7.37630031e-03,
#         4.99999844e-01, 4.45165229e-04]]), array([207.17542413, 207.17544101, 207.17544708, 207.17544757,
#        207.17545357, 207.17546096, 207.17546348]))
#            fun: 207.1754241278831
#        message: 'Optimization terminated successfully.'
#           nfev: 260
#            nit: 153
#         status: 0
#        success: True
#              x: array([2.03267794e-01, 8.17791332e-05, 8.51021696e-02, 7.37370391e-03,
#        4.99999988e-01, 4.45353617e-04])
# tempo esecuzione : 913.51571

# %%
import matplotlib.pyplot as plt
import numpy as np
def x_fun_espl(t, alpha, kappa, Y_0):
    y = kappa * np.exp( np.log(Y_0/kappa) *  np.exp(- alpha* t))
    return y

# %%
s_= 6
SAEM.select_subj(s_)
plt.plot(SAEM.timei, SAEM.yobsi, "r*")
tempo = np.linspace(0.0, 25, 25000)
x_hat_medio = x_fun_espl(tempo,  SAEM.theta_choose[0], SAEM.theta_choose[1], 1e-7)  
x_hati = x_fun_espl(tempo, SAEM.PhiALL[SAEM.iterazione,s_ - 1, 0], SAEM.PhiALL[SAEM.iterazione,s_ -1, 1], 1e-7)  
plt.plot(tempo, x_hati, "g-", label = "ultimi phii") 
plt.plot(tempo, x_hat_medio, label = "medio popolazione")
plt.legend()
