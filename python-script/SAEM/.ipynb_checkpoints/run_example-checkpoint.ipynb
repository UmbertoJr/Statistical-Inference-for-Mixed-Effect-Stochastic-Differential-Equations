# %%
from SAEM import Stochasti_Approximation_Expectation_Maximization
from time import time

# %%
start = time()
# self.PARMIN = [0.01, 1e-6, 0.0001, 1e-5, 0.0001, 1e-5] ; self.PARMAX = [1, 1e-1, 0.05, 1e-1, 1, 1e-3]
#theta = [0.3, 0.009, 0.2, 0.3, 0.3, 0.0001]   # [0.27, 0.0005, 0.04, 0.0035, 0.18, 0.0001]
theta = [0.089, 0.0034, 0.2 , 0.2, 0.1, 5e-5] 
SAEM = Stochasti_Approximation_Expectation_Maximization()
#SAEM.inizializza(theta)
SAEM.run(theta)
print("tempo esecuzione : %.5f "% (time()-start))
# Out:
# ### ottimizazione iterazione :  0
# 	acceptance rate = 0.2833  for subject 1
# 	phi scelti: (1.021e-01 , 2.140e-03)  marginal y 5.1278e+77
# 	acceptance rate = 0.3200  for subject 2
# 	phi scelti: (9.768e-02 , 3.843e-03)  marginal y 2.2359e+67
# 	acceptance rate = 0.4967  for subject 3
# 	phi scelti: (1.228e-01 , 5.189e-04)  marginal y 6.1425e+83
# 	acceptance rate = 0.4033  for subject 4
# 	phi scelti: (1.402e-01 , 7.968e-04)  marginal y 2.2347e+62
# 	acceptance rate = 0.2367  for subject 5
# 	phi scelti: (1.243e-01 , 1.377e-03)  marginal y 7.5473e+91
# 	acceptance rate = 0.5267  for subject 6
# 	phi scelti: (1.117e-01 , 1.329e-03)  marginal y 1.1709e+63
#  final_simplex: (array([[9.345e-02, 3.400e-03, 2.000e-01, 2.000e-01, 1.000e-01, 5.000e-05],
#        [9.345e-02, 3.400e-03, 2.000e-01, 2.000e-01, 1.000e-01, 5.000e-05],
#        [9.345e-02, 3.400e-03, 2.000e-01, 2.000e-01, 1.000e-01, 5.000e-05],
#        [9.345e-02, 3.400e-03, 2.000e-01, 2.000e-01, 1.000e-01, 5.000e-05],
#        [9.345e-02, 3.400e-03, 2.000e-01, 2.000e-01, 1.000e-01, 5.000e-05],
#        [9.345e-02, 3.400e-03, 2.000e-01, 2.000e-01, 1.000e-01, 5.000e-05],
#        [9.345e-02, 3.400e-03, 2.000e-01, 2.000e-01, 1.000e-01, 5.000e-05]]), array([-1380.07063545, -1380.07063545, -1380.07063545, -1380.07063545,
#        -1380.07063545, -1380.07063545, -1380.07063545]))
#            fun: -1380.0706354479282
#        message: 'Optimization terminated successfully.'
#           nfev: 400
#            nit: 51
#         status: 0
#        success: True
#              x: array([9.345e-02, 3.400e-03, 2.000e-01, 2.000e-01, 1.000e-01, 5.000e-05])
# ### ottimizazione iterazione :  1
# 	acceptance rate = 0.3300  for subject 1
# 	phi scelti: (1.046e-01 , 1.938e-03)  marginal y 4.5067e+77
# 	acceptance rate = 0.3500  for subject 2
# 	phi scelti: (1.087e-01 , 2.438e-03)  marginal y 2.0479e+67
# 	acceptance rate = 0.4867  for subject 3
# 	phi scelti: (1.194e-01 , 5.530e-04)  marginal y 9.2420e+83
# 	acceptance rate = 0.4233  for subject 4
# 	phi scelti: (1.314e-01 , 9.854e-04)  marginal y 2.2765e+62
# 	acceptance rate = 0.2167  for subject 5
# 	phi scelti: (1.163e-01 , 1.782e-03)  marginal y 1.0049e+92
# 	acceptance rate = 0.5233  for subject 6
# 	phi scelti: (1.231e-01 , 1.023e-03)  marginal y 1.3077e+63
#  final_simplex: (array([[9.81225e-02, 3.40000e-03, 2.00000e-01, 2.00000e-01, 1.00000e-01,
#         5.00000e-05],
#        [9.81225e-02, 3.40000e-03, 2.00000e-01, 2.00000e-01, 1.00000e-01,
#         5.00000e-05],
#        [9.81225e-02, 3.40000e-03, 2.00000e-01, 2.00000e-01, 1.00000e-01,
#         5.00000e-05],
#        [9.81225e-02, 3.40000e-03, 2.00000e-01, 2.00000e-01, 1.00000e-01,
#         5.00000e-05],
#        [9.81225e-02, 3.40000e-03, 2.00000e-01, 2.00000e-01, 1.00000e-01,
#         5.00000e-05],
#        [9.81225e-02, 3.40000e-03, 2.00000e-01, 2.00000e-01, 1.00000e-01,
#         5.00000e-05],
#        [9.81225e-02, 3.40000e-03, 2.00000e-01, 2.00000e-01, 1.00000e-01,
#         5.00000e-05]]), array([-1407.06544098, -1407.06544098, -1407.06544098, -1407.06544098,
#        -1407.06544098, -1407.06544098, -1407.06544098]))
#            fun: -1407.0654409756894
#        message: 'Optimization terminated successfully.'
#           nfev: 400
#            nit: 51
#         status: 0
#        success: True
#              x: array([9.81225e-02, 3.40000e-03, 2.00000e-01, 2.00000e-01, 1.00000e-01,
#        5.00000e-05])
# ### ottimizazione iterazione :  2
# 	acceptance rate = 0.2900  for subject 1
# 	phi scelti: (1.074e-01 , 1.708e-03)  marginal y 5.2598e+77
# 	acceptance rate = 0.2700  for subject 2
# 	phi scelti: (1.035e-01 , 2.734e-03)  marginal y 1.5012e+67
# 	acceptance rate = 0.5200  for subject 3
# 	phi scelti: (1.334e-01 , 4.102e-04)  marginal y 6.8548e+83
# 	acceptance rate = 0.3333  for subject 4
# 	phi scelti: (1.378e-01 , 7.911e-04)  marginal y 2.3671e+62
# 	acceptance rate = 0.1500  for subject 5
# 	phi scelti: (1.238e-01 , 1.383e-03)  marginal y 7.4578e+91
# 	acceptance rate = 0.5433  for subject 6
# 	phi scelti: (1.357e-01 , 6.610e-04)  marginal y 1.1445e+63
#  final_simplex: (array([[1.03028625e-01, 3.40000000e-03, 2.00000000e-01, 2.00000000e-01,
#         1.00000000e-01, 5.00000000e-05],
#        [1.03028625e-01, 3.40000000e-03, 2.00000000e-01, 2.00000000e-01,
#         1.00000000e-01, 5.00000000e-05],
#        [1.03028625e-01, 3.40000000e-03, 2.00000000e-01, 2.00000000e-01,
#         1.00000000e-01, 5.00000000e-05],
#        [1.03028625e-01, 3.40000000e-03, 2.00000000e-01, 2.00000000e-01,
#         1.00000000e-01, 5.00000000e-05],
#        [1.03028625e-01, 3.40000000e-03, 2.00000000e-01, 2.00000000e-01,
#         1.00000000e-01, 5.00000000e-05],
#        [1.03028625e-01, 3.40000000e-03, 2.00000000e-01, 2.00000000e-01,
#         1.00000000e-01, 5.00000000e-05],
#        [1.03028625e-01, 3.40000000e-03, 2.00000000e-01, 2.00000000e-01,
#         1.00000000e-01, 5.00000000e-05]]), array([-1364.03591897, -1364.03591897, -1364.03591897, -1364.03591897,
#        -1364.03591897, -1364.03591897, -1364.03591897]))
#            fun: -1364.035918968975
#        message: 'Optimization terminated successfully.'
#           nfev: 400
#            nit: 51
#         status: 0
#        success: True
#              x: array([1.03028625e-01, 3.40000000e-03, 2.00000000e-01, 2.00000000e-01,
#        1.00000000e-01, 5.00000000e-05])
# ### ottimizazione iterazione :  3
# 	acceptance rate = 0.3367  for subject 1
# 	phi scelti: (1.128e-01 , 1.329e-03)  marginal y 3.7007e+77
# 	acceptance rate = 0.2867  for subject 2
# 	phi scelti: (1.035e-01 , 2.734e-03)  marginal y 1.2965e+67
# 	acceptance rate = 0.4800  for subject 3
# 	phi scelti: (1.288e-01 , 4.732e-04)  marginal y 6.2920e+83
# 	acceptance rate = 0.3600  for subject 4
# 	phi scelti: (1.384e-01 , 8.664e-04)  marginal y 2.8667e+62
# 	acceptance rate = 0.1633  for subject 5
# 	phi scelti: (1.303e-01 , 1.281e-03)  marginal y 4.0089e+91
# 	acceptance rate = 0.5200  for subject 6
# 	phi scelti: (1.357e-01 , 6.610e-04)  marginal y 1.1831e+63

# %%
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2,figsize=(15,10))
ax1.plot(-SAEM.log_lik_history, label= "log loss - iterations"); 
ax2.plot(SAEM.theta_history[0,:], SAEM.theta_history[1,:], label= "kappa - alpha")
ax3.plot(SAEM.theta_history[0,:], label= "alpha - iteration", color= "green");
ax4.plot(SAEM.theta_history[1,:], label= "kappa - iteration", color= "orange")
ax1.legend();ax2.legend(); ax3.legend(); ax4.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
def x_fun_espl(t, alpha, kappa, Y_0):
    y = kappa * np.exp( np.log(Y_0/kappa) *  np.exp(- alpha* t))
    return y

# %%
for s_ in range(1,7):
    SAEM.select_subj(s_)
    c_r = tuple(np.random.rand(1,3).tolist()[0])
    plt.plot(SAEM.timei, SAEM.yobsi, "*", color= c_r)
    tempo = np.linspace(0.0, 25, 25000)
    x_hat_medio = x_fun_espl(tempo,  SAEM.theta_choose[0], SAEM.theta_choose[1], 1e-7)  
    x_hati = x_fun_espl(tempo, SAEM.PhiALL[SAEM.iterazione,s_ - 1, 0], SAEM.PhiALL[SAEM.iterazione,s_ -1, 1], 1e-7)  
    plt.plot(tempo, x_hati, "g-", label = "ultimi phii PMCMC", color= c_r) 
plt.plot(tempo, x_hat_medio, label = "medio popolazione", color="black")
plt.legend()

# %%
s_=2
SAEM.select_subj(s_)
c_r = tuple(np.random.rand(1,3).tolist()[0])
plt.plot(SAEM.timei, SAEM.yobsi, "*", color= c_r)
tempo = np.linspace(0.0, 25, 25000)
x_hat_medio = x_fun_espl(tempo,  SAEM.theta_choose[0], SAEM.theta_choose[1], 1e-7)  
x_hati = x_fun_espl(tempo, SAEM.PhiALL[SAEM.iterazione,s_ - 1, 0], SAEM.PhiALL[SAEM.iterazione,s_ -1, 1], 1e-7)  
plt.plot(tempo, x_hati, "g-", label = "ultimi phii PMCMC", color= c_r)
