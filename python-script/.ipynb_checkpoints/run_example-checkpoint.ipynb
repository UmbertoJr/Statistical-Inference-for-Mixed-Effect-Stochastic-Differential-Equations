# %%
from SAEM import Stochasti_Approximation_Expectation_Maximization
from time import time

# %%
start = time()
# self.PARMIN = [0.01, 1e-6, 0.0001, 1e-5, 0.0001, 1e-5] ; self.PARMAX = [1, 1e-1, 0.05, 1e-1, 1, 1e-3]
theta = [0.3, 0.009, 0.2, 0.3, 0.3, 0.0001]   # [0.27, 0.0005, 0.04, 0.0035, 0.18, 0.0001]
SAEM = Stochasti_Approximation_Expectation_Maximization()
#SAEM.inizializza(theta)
SAEM.run(theta)
print("tempo esecuzione : %.5f "% (time()-start))
# Out:
# ### ottimizazione iterazione :  0
# 	acceptance rate = 0.5000  for subject 1
# 	phi scelti: (1.369e-01 , 3.490e-03)  marginal y 4.3992e+72
# C:\Users\Umbertojunior\Desktop\data science\tesi\python-script\particle_markov_chain_monte_carlo.py:166: RuntimeWarning: overflow encountered in double_scalars
#   prob_acceptance = np.min([1. , num/den ])
# 	acceptance rate = 0.5000  for subject 2
# 	phi scelti: (1.422e-01 , 4.601e-03)  marginal y 3.7551e+63
# 	acceptance rate = 0.1200  for subject 3
# 	phi scelti: (3.626e-01 , 7.783e-03)  marginal y 3.1029e+61
# 	acceptance rate = 0.0500  for subject 4
# 	phi scelti: (2.964e-01 , 1.137e-02)  marginal y 2.8425e+45
# 	acceptance rate = 0.1700  for subject 5
# 	phi scelti: (1.193e-01 , 5.473e-03)  marginal y 1.0174e+85
# 	acceptance rate = 0.6000  for subject 6
# 	phi scelti: (1.329e-01 , 2.747e-03)  marginal y 1.1952e+59
#  final_simplex: (array([[1.81008082e-01, 4.71922566e-03, 2.29564120e-01, 3.14995048e-03,
#         6.49271581e-01, 1.35308303e-04],
#        [1.81082716e-01, 4.72039798e-03, 2.29549476e-01, 3.15011608e-03,
#         6.49207372e-01, 1.35287830e-04],
#        [1.81059841e-01, 4.71976277e-03, 2.29554595e-01, 3.14944066e-03,
#         6.49183964e-01, 1.35304039e-04],
#        [1.80965809e-01, 4.72184602e-03, 2.29623455e-01, 3.15012628e-03,
#         6.49235062e-01, 1.35301311e-04],
#        [1.81061944e-01, 4.71937723e-03, 2.29544763e-01, 3.15064110e-03,
#         6.49222859e-01, 1.35300454e-04],
#        [1.80985832e-01, 4.71975116e-03, 2.29576533e-01, 3.15152124e-03,
#         6.49327888e-01, 1.35299761e-04],
#        [1.81025909e-01, 4.72056056e-03, 2.29576001e-01, 3.14836405e-03,
#         6.49244225e-01, 1.35295641e-04]]), array([714.34945797, 714.34945867, 714.34945901, 714.34946   ,
#        714.34946095, 714.34946154, 714.34946206]))
#            fun: 714.3494579675943
#        message: 'Optimization terminated successfully.'
#           nfev: 392
#            nit: 233
#         status: 0
#        success: True
#              x: array([1.81008082e-01, 4.71922566e-03, 2.29564120e-01, 3.14995048e-03,
#        6.49271581e-01, 1.35308303e-04])
# ### ottimizazione iterazione :  1
# 	acceptance rate = 0.2800  for subject 1
# 	phi scelti: (1.343e-01 , 9.398e-04)  marginal y 2.8641e+69
# 	acceptance rate = 0.4600  for subject 2
# 	phi scelti: (1.301e-01 , 4.372e-03)  marginal y 1.1409e+61
# 	acceptance rate = 0.6700  for subject 3
# 	phi scelti: (7.960e-02 , 4.409e-03)  marginal y 2.2944e+75
# 	acceptance rate = 0.3700  for subject 4
# 	phi scelti: (1.245e-01 , 7.404e-03)  marginal y 5.1517e+54
# 	acceptance rate = 0.1400  for subject 5
# 	phi scelti: (1.085e-01 , 3.649e-03)  marginal y 1.2672e+79
# 	acceptance rate = 0.8500  for subject 6
# 	phi scelti: (1.463e-01 , 2.074e-03)  marginal y 1.1739e+57
#  final_simplex: (array([[1.09296902e-01, 6.70735628e-03, 2.89357292e-02, 2.81193987e-03,
#         9.83814537e-01, 1.27537859e-04],
#        [1.09324874e-01, 6.70722170e-03, 2.88625892e-02, 2.81174431e-03,
#         9.83813431e-01, 1.27658505e-04],
#        [1.09394810e-01, 6.70946219e-03, 2.88455217e-02, 2.80947006e-03,
#         9.83814231e-01, 1.27639632e-04],
#        [1.09321532e-01, 6.70804950e-03, 2.88975351e-02, 2.81128589e-03,
#         9.83813150e-01, 1.27573617e-04],
#        [1.09392597e-01, 6.70919064e-03, 2.89285768e-02, 2.80940178e-03,
#         9.83813922e-01, 1.27554354e-04],
#        [1.09380144e-01, 6.70972451e-03, 2.88570307e-02, 2.80956048e-03,
#         9.83814011e-01, 1.27598312e-04],
#        [1.09333377e-01, 6.70845323e-03, 2.88624491e-02, 2.81098469e-03,
#         9.83812988e-01, 1.27606713e-04]]), array([3341.24654289, 3341.24657352, 3341.24659874, 3341.2466032 ,
#        3341.24660479, 3341.24662354, 3341.24663039]))
#            fun: 3341.246542894133
#        message: 'Optimization terminated successfully.'
#           nfev: 387
#            nit: 232
#         status: 0
#        success: True
#              x: array([1.09296902e-01, 6.70735628e-03, 2.89357292e-02, 2.81193987e-03,
#        9.83814537e-01, 1.27537859e-04])
# ### ottimizazione iterazione :  2
# 	acceptance rate = 0.1000  for subject 1
# 	phi scelti: (1.443e-01 , 1.155e-03)  marginal y 2.1669e+67
# 	acceptance rate = 0.1400  for subject 2
# 	phi scelti: (8.914e-02 , 3.348e-03)  marginal y 2.1699e+59
# 	acceptance rate = 0.7700  for subject 3
# 	phi scelti: (7.960e-02 , 4.409e-03)  marginal y 9.5124e+74
# 	acceptance rate = 0.1900  for subject 4
# 	phi scelti: (7.424e-02 , 5.059e-03)  marginal y 1.0707e+54
# 	acceptance rate = 0.0600  for subject 5
# 	phi scelti: (1.096e-01 , 3.115e-03)  marginal y 1.8711e+75
# 	acceptance rate = 0.7700  for subject 6
# 	phi scelti: (1.075e-01 , 3.281e-03)  marginal y 4.5417e+56
#  final_simplex: (array([[1.00268795e-01, 3.47841848e-03, 2.70573163e-02, 1.18973681e-03,
#         9.99999732e-01, 1.36919237e-04],
#        [1.00313307e-01, 3.47983772e-03, 2.70548368e-02, 1.19022042e-03,
#         9.99999682e-01, 1.36975051e-04],
#        [1.00335893e-01, 3.48054488e-03, 2.70435426e-02, 1.18893860e-03,
#         9.99999306e-01, 1.36910303e-04],
#        [1.00293058e-01, 3.47940173e-03, 2.70460156e-02, 1.18802886e-03,
#         9.99999975e-01, 1.36955122e-04],
#        [1.00327377e-01, 3.47968775e-03, 2.70521911e-02, 1.18953946e-03,
#         9.99999114e-01, 1.36935468e-04],
#        [1.00301444e-01, 3.48097079e-03, 2.70423089e-02, 1.18979719e-03,
#         9.99998356e-01, 1.36940829e-04],
#        [1.00235198e-01, 3.48040545e-03, 2.70326900e-02, 1.18733541e-03,
#         9.99999797e-01, 1.37007375e-04]]), array([3420.978658  , 3420.97868151, 3420.97870915, 3420.97871057,
#        3420.97872123, 3420.97874241, 3420.97875354]))
#            fun: 3420.9786580033133
#        message: 'Optimization terminated successfully.'
#           nfev: 419
#            nit: 261
#         status: 0
#        success: True
#              x: array([1.00268795e-01, 3.47841848e-03, 2.70573163e-02, 1.18973681e-03,
#        9.99999732e-01, 1.36919237e-04])
# ### ottimizazione iterazione :  3
# 	acceptance rate = 0.0900  for subject 1
# 	phi scelti: (1.122e-01 , 7.017e-04)  marginal y 5.0975e+67
# 	acceptance rate = 0.1600  for subject 2
# 	phi scelti: (1.024e-01 , 3.175e-03)  marginal y 2.2042e+59
# 	acceptance rate = 0.8200  for subject 3
# 	phi scelti: (5.347e-02 , 4.946e-03)  marginal y 3.3203e+74
# 	acceptance rate = 0.2200  for subject 4
# 	phi scelti: (6.319e-02 , 3.761e-03)  marginal y 1.9414e+53
# 	acceptance rate = 0.0600  for subject 5
# 	phi scelti: (3.822e-02 , 4.723e-03)  marginal y 4.0198e+73
# 	acceptance rate = 0.7500  for subject 6
# 	phi scelti: (8.986e-02 , 3.032e-03)  marginal y 3.4887e+56
#  final_simplex: (array([[7.66113235e-02, 3.37079704e-03, 2.70064372e-02, 1.38826329e-03,
#         9.99999554e-01, 1.26569918e-04],
#        [7.66963397e-02, 3.36834400e-03, 2.69706479e-02, 1.38884432e-03,
#         9.99999457e-01, 1.26550108e-04],
#        [7.66934482e-02, 3.37128666e-03, 2.70096458e-02, 1.38822916e-03,
#         9.99999411e-01, 1.26548693e-04],
#        [7.66294985e-02, 3.37014773e-03, 2.70003716e-02, 1.38810285e-03,
#         9.99999325e-01, 1.26597161e-04],
#        [7.66299372e-02, 3.37096991e-03, 2.70156897e-02, 1.38819355e-03,
#         9.99998539e-01, 1.26569278e-04],
#        [7.65457682e-02, 3.36976700e-03, 2.70233304e-02, 1.38873883e-03,
#         9.99999315e-01, 1.26550046e-04],
#        [7.66612297e-02, 3.37166491e-03, 2.70003746e-02, 1.38759583e-03,
#         9.99998096e-01, 1.26614310e-04]]), array([3310.81497101, 3310.81501099, 3310.81502194, 3310.81503596,
#        3310.81504537, 3310.81505454, 3310.81506094]))
#            fun: 3310.81497101366
#        message: 'Optimization terminated successfully.'
#           nfev: 366
#            nit: 227
#         status: 0
#        success: True
#              x: array([7.66113235e-02, 3.37079704e-03, 2.70064372e-02, 1.38826329e-03,
#        9.99999554e-01, 1.26569918e-04])
# ### ottimizazione iterazione :  4
# 	acceptance rate = 0.0800  for subject 1
# 	phi scelti: (8.930e-02 , 7.376e-04)  marginal y 4.0161e+66
# 	acceptance rate = 0.1700  for subject 2
# 	phi scelti: (1.262e-01 , 1.358e-03)  marginal y 3.0236e+59
# 	acceptance rate = 0.8000  for subject 3
# 	phi scelti: (3.010e-02 , 1.373e-03)  marginal y 4.6867e+74
# 	acceptance rate = 0.2000  for subject 4
# 	phi scelti: (6.366e-02 , 2.857e-03)  marginal y 2.3838e+53
# 	acceptance rate = 0.0500  for subject 5
# 	phi scelti: (5.194e-02 , 5.038e-03)  marginal y 6.4359e+73
# 	acceptance rate = 0.8900  for subject 6
# 	phi scelti: (9.008e-02 , 5.362e-03)  marginal y 3.6473e+56
#  final_simplex: (array([[7.52103361e-02, 2.78771240e-03, 3.08952988e-02, 1.82337328e-03,
#         7.03123537e-01, 1.84561348e-04],
#        [7.52088115e-02, 2.78770526e-03, 3.08961631e-02, 1.82333034e-03,
#         7.03077184e-01, 1.84563216e-04],
#        [7.52109065e-02, 2.78769124e-03, 3.08960945e-02, 1.82334466e-03,
#         7.03079241e-01, 1.84562484e-04],
#        [7.52092826e-02, 2.78772410e-03, 3.08957448e-02, 1.82337663e-03,
#         7.03187844e-01, 1.84564091e-04],
#        [7.52112961e-02, 2.78775925e-03, 3.08949689e-02, 1.82332744e-03,
#         7.03111256e-01, 1.84562028e-04],
#        [7.52112094e-02, 2.78771390e-03, 3.08953485e-02, 1.82341192e-03,
#         7.03100959e-01, 1.84562414e-04],
#        [7.52102962e-02, 2.78780927e-03, 3.08965285e-02, 1.82332657e-03,
#         7.03123180e-01, 1.84561486e-04]]), array([3485.61674141, 3485.61674142, 3485.61674142, 3485.61674142,
#        3485.61674143, 3485.61674143, 3485.61674143]))
#            fun: 3485.6167414144043
#        message: 'Optimization terminated successfully.'
#           nfev: 337
#            nit: 208
#         status: 0
#        success: True
#              x: array([7.52103361e-02, 2.78771240e-03, 3.08952988e-02, 1.82337328e-03,
#        7.03123537e-01, 1.84561348e-04])
# ### ottimizazione iterazione :  5
# 	acceptance rate = 0.2100  for subject 1
# 	phi scelti: (1.033e-01 , 7.952e-04)  marginal y 1.0836e+67
# 	acceptance rate = 0.4200  for subject 2
# 	phi scelti: (1.579e-01 , 1.139e-03)  marginal y 1.9520e+59
# 	acceptance rate = 0.9200  for subject 3
# 	phi scelti: (2.371e-02 , 1.720e-03)  marginal y 7.5502e+73
# 	acceptance rate = 0.7800  for subject 4
# 	phi scelti: (1.165e-01 , 7.017e-04)  marginal y 5.6654e+53
# 	acceptance rate = 0.0100  for subject 5
# 	phi scelti: (6.025e-02 , 5.244e-03)  marginal y 6.8609e+76
# 	acceptance rate = 0.8000  for subject 6
# 	phi scelti: (9.368e-02 , 2.987e-03)  marginal y 1.0398e+56
#  final_simplex: (array([[8.86521862e-02, 1.41760392e-03, 3.50699179e-02, 2.35643005e-03,
#         9.99999977e-01, 1.76138276e-04],
#        [8.86485855e-02, 1.41487977e-03, 3.50792501e-02, 2.35514948e-03,
#         9.99999960e-01, 1.76130592e-04],
#        [8.86683151e-02, 1.41860518e-03, 3.50310463e-02, 2.35410861e-03,
#         9.99999840e-01, 1.76109300e-04],
#        [8.87200833e-02, 1.41647165e-03, 3.50781368e-02, 2.35733826e-03,
#         9.99999837e-01, 1.76135468e-04],
#        [8.86798479e-02, 1.41697310e-03, 3.50651611e-02, 2.35602596e-03,
#         9.99999652e-01, 1.76131130e-04],
#        [8.86525769e-02, 1.41238483e-03, 3.50893601e-02, 2.35374784e-03,
#         9.99999749e-01, 1.76099386e-04],
#        [8.86817426e-02, 1.41682299e-03, 3.50721962e-02, 2.35629264e-03,
#         9.99999531e-01, 1.76122592e-04]]), array([3380.26126142, 3380.26127178, 3380.26127209, 3380.26127622,
#        3380.26128625, 3380.26128763, 3380.26129275]))
#            fun: 3380.2612614199024
#        message: 'Optimization terminated successfully.'
#           nfev: 653
#            nit: 406
#         status: 0
#        success: True
#              x: array([8.86521862e-02, 1.41760392e-03, 3.50699179e-02, 2.35643005e-03,
#        9.99999977e-01, 1.76138276e-04])
# ### ottimizazione iterazione :  6
# 	acceptance rate = 0.1700  for subject 1
# 	phi scelti: (8.326e-02 , 7.703e-04)  marginal y 3.5798e+66
# 	acceptance rate = 0.3200  for subject 2
# 	phi scelti: (1.259e-01 , 8.719e-04)  marginal y 6.9383e+58
# 	acceptance rate = 0.9600  for subject 3
# 	phi scelti: (2.770e-02 , 1.622e-03)  marginal y 1.0015e+74
# 	acceptance rate = 0.4600  for subject 4
# 	phi scelti: (1.230e-01 , 5.706e-04)  marginal y 7.1077e+53
# 	acceptance rate = 0.0500  for subject 5
# 	phi scelti: (6.370e-02 , 6.548e-03)  marginal y 2.1921e+75
# 	acceptance rate = 0.9200  for subject 6
# 	phi scelti: (7.359e-02 , 2.857e-03)  marginal y 6.1253e+55
#  final_simplex: (array([[8.28676782e-02, 2.20669456e-03, 3.40725174e-02, 2.08688997e-03,
#         7.69179380e-01, 1.71341219e-04],
#        [8.28677531e-02, 2.20644919e-03, 3.40708184e-02, 2.08671550e-03,
#         7.69255511e-01, 1.71340120e-04],
#        [8.28713833e-02, 2.20659125e-03, 3.40716714e-02, 2.08680913e-03,
#         7.69162439e-01, 1.71343898e-04],
#        [8.28679916e-02, 2.20660598e-03, 3.40734241e-02, 2.08678613e-03,
#         7.69142542e-01, 1.71337795e-04],
#        [8.28696157e-02, 2.20650317e-03, 3.40742169e-02, 2.08677834e-03,
#         7.69222153e-01, 1.71342360e-04],
#        [8.28651991e-02, 2.20670416e-03, 3.40718416e-02, 2.08676233e-03,
#         7.69114023e-01, 1.71341885e-04],
#        [8.28644295e-02, 2.20643701e-03, 3.40699501e-02, 2.08683592e-03,
#         7.69186479e-01, 1.71338827e-04]]), array([3480.62128823, 3480.62128827, 3480.62128827, 3480.62128828,
#        3480.62128828, 3480.62128829, 3480.62128829]))
#            fun: 3480.6212882338946
#        message: 'Optimization terminated successfully.'
#           nfev: 221
#            nit: 131
#         status: 0
#        success: True
#              x: array([8.28676782e-02, 2.20669456e-03, 3.40725174e-02, 2.08688997e-03,
#        7.69179380e-01, 1.71341219e-04])
# ### ottimizazione iterazione :  7
# 	acceptance rate = 0.0900  for subject 1
# 	phi scelti: (8.829e-02 , 5.796e-04)  marginal y 1.3399e+67
# 	acceptance rate = 0.4100  for subject 2
# 	phi scelti: (1.335e-01 , 9.420e-04)  marginal y 5.3621e+58
# 	acceptance rate = 0.9400  for subject 3
# 	phi scelti: (5.679e-02 , 1.750e-03)  marginal y 1.8603e+74
# 	acceptance rate = 0.3800  for subject 4
# 	phi scelti: (1.029e-01 , 5.837e-04)  marginal y 1.9789e+54
# 	acceptance rate = 0.0200  for subject 5
# 	phi scelti: (6.617e-02 , 5.740e-03)  marginal y 2.0470e+76
# 	acceptance rate = 0.8100  for subject 6
# 	phi scelti: (1.157e-01 , 2.111e-03)  marginal y 1.2259e+56
#  final_simplex: (array([[9.37250847e-02, 2.47581883e-03, 3.06608991e-02, 2.13038356e-03,
#         9.99999734e-01, 1.41716035e-04],
#        [9.38077227e-02, 2.47505594e-03, 3.06293904e-02, 2.13293877e-03,
#         9.99999452e-01, 1.41737307e-04],
#        [9.37395188e-02, 2.47699697e-03, 3.06627419e-02, 2.12998451e-03,
#         9.99999883e-01, 1.41677281e-04],
#        [9.38226811e-02, 2.47569986e-03, 3.06413017e-02, 2.13188781e-03,
#         9.99999219e-01, 1.41720621e-04],
#        [9.36759114e-02, 2.47727268e-03, 3.05936946e-02, 2.13520288e-03,
#         9.99999058e-01, 1.41637687e-04],
#        [9.37828669e-02, 2.47859862e-03, 3.06030027e-02, 2.13418681e-03,
#         9.99999433e-01, 1.41603249e-04],
#        [9.38091490e-02, 2.47598861e-03, 3.06522267e-02, 2.13099406e-03,
#         9.99999224e-01, 1.41713556e-04]]), array([3400.00505902, 3400.00507165, 3400.00507269, 3400.00514037,
#        3400.0051429 , 3400.0051452 , 3400.00515198]))
#            fun: 3400.005059022287
#        message: 'Optimization terminated successfully.'
#           nfev: 463
#            nit: 285
#         status: 0
#        success: True
#              x: array([9.37250847e-02, 2.47581883e-03, 3.06608991e-02, 2.13038356e-03,
#        9.99999734e-01, 1.41716035e-04])
# ### ottimizazione iterazione :  8
# 	acceptance rate = 0.1400  for subject 1
# 	phi scelti: (1.232e-01 , 5.854e-04)  marginal y 4.2588e+66
# 	acceptance rate = 0.0900  for subject 2
# 	phi scelti: (9.196e-02 , 9.779e-04)  marginal y 2.9147e+59
# 	acceptance rate = 0.8700  for subject 3
# 	phi scelti: (4.547e-02 , 1.361e-03)  marginal y 4.5878e+74
# 	acceptance rate = 0.2000  for subject 4
# 	phi scelti: (1.223e-01 , 3.907e-04)  marginal y 1.0181e+54
# 	acceptance rate = 0.0600  for subject 5
# 	phi scelti: (7.324e-02 , 6.508e-03)  marginal y 1.1910e+75
# 	acceptance rate = 0.8300  for subject 6
# 	phi scelti: (9.343e-02 , 9.946e-04)  marginal y 3.6554e+56
#  final_simplex: (array([[9.16031137e-02, 1.80303154e-03, 2.71136924e-02, 2.12667882e-03,
#         8.74314479e-01, 1.30231300e-04],
#        [9.15984949e-02, 1.80303838e-03, 2.71160912e-02, 2.12653241e-03,
#         8.74350328e-01, 1.30243813e-04],
#        [9.16033655e-02, 1.80249136e-03, 2.71176964e-02, 2.12701213e-03,
#         8.74286944e-01, 1.30234305e-04],
#        [9.16002266e-02, 1.80321147e-03, 2.71178872e-02, 2.12648462e-03,
#         8.74359095e-01, 1.30233184e-04],
#        [9.16035050e-02, 1.80233812e-03, 2.71138026e-02, 2.12647371e-03,
#         8.74242497e-01, 1.30232088e-04],
#        [9.16019539e-02, 1.80321796e-03, 2.71198694e-02, 2.12706078e-03,
#         8.74323155e-01, 1.30233814e-04],
#        [9.15912260e-02, 1.80314928e-03, 2.71147692e-02, 2.12662620e-03,
#         8.74269006e-01, 1.30229746e-04]]), array([3455.77551494, 3455.77551495, 3455.77551517, 3455.77551522,
#        3455.77551527, 3455.77551536, 3455.77551537]))
#            fun: 3455.775514939197
#        message: 'Optimization terminated successfully.'
#           nfev: 217
#            nit: 129
#         status: 0
#        success: True
#              x: array([9.16031137e-02, 1.80303154e-03, 2.71136924e-02, 2.12667882e-03,
#        8.74314479e-01, 1.30231300e-04])
# ### ottimizazione iterazione :  9
# 	acceptance rate = 0.2300  for subject 1
# 	phi scelti: (1.212e-01 , 1.032e-03)  marginal y 5.5700e+67
# 	acceptance rate = 0.1500  for subject 2
# 	phi scelti: (9.835e-02 , 8.566e-04)  marginal y 5.1440e+59
# 	acceptance rate = 0.8300  for subject 3
# 	phi scelti: (1.293e-01 , 2.964e-04)  marginal y 1.3714e+75
# 	acceptance rate = 0.1800  for subject 4
# 	phi scelti: (1.183e-01 , 2.920e-04)  marginal y 9.1482e+53
# 	acceptance rate = 0.1000  for subject 5
# 	phi scelti: (9.963e-02 , 6.535e-03)  marginal y 7.9477e+75
# 	acceptance rate = 0.8600  for subject 6
# 	phi scelti: (1.321e-01 , 7.041e-04)  marginal y 5.4161e+56
#  final_simplex: (array([[1.16495661e-01, 1.61915858e-03, 1.32127355e-02, 2.21495124e-03,
#         9.30982448e-01, 1.53097688e-04],
#        [1.16496305e-01, 1.61920133e-03, 1.32125045e-02, 2.21484996e-03,
#         9.31023929e-01, 1.53096510e-04],
#        [1.16494848e-01, 1.61935361e-03, 1.32124741e-02, 2.21502961e-03,
#         9.30917102e-01, 1.53097080e-04],
#        [1.16495354e-01, 1.61944645e-03, 1.32126154e-02, 2.21501963e-03,
#         9.30932719e-01, 1.53095058e-04],
#        [1.16494889e-01, 1.61935258e-03, 1.32115596e-02, 2.21495567e-03,
#         9.30981747e-01, 1.53096365e-04],
#        [1.16494197e-01, 1.61942898e-03, 1.32131788e-02, 2.21489635e-03,
#         9.31000116e-01, 1.53097564e-04],
#        [1.16496544e-01, 1.61935093e-03, 1.32126233e-02, 2.21488811e-03,
#         9.31056921e-01, 1.53101031e-04]]), array([3465.61229336, 3465.61229336, 3465.61229336, 3465.61229336,
#        3465.61229338, 3465.61229339, 3465.61229343]))
#            fun: 3465.6122933584575
#        message: 'Optimization terminated successfully.'
#           nfev: 327
#            nit: 203
#         status: 0
#        success: True
#              x: array([1.16495661e-01, 1.61915858e-03, 1.32127355e-02, 2.21495124e-03,
#        9.30982448e-01, 1.53097688e-04])
# ### ottimizazione iterazione :  10
# 	acceptance rate = 0.1900  for subject 1
# 	phi scelti: (1.092e-01 , 1.061e-03)  marginal y 1.0354e+67
# 	acceptance rate = 0.2500  for subject 2
# 	phi scelti: (1.306e-01 , 8.290e-04)  marginal y 1.2852e+59
# 	acceptance rate = 0.6400  for subject 3
# 	phi scelti: (1.257e-01 , 1.997e-04)  marginal y 5.7021e+74
# 	acceptance rate = 0.2900  for subject 4
# 	phi scelti: (1.236e-01 , 2.533e-04)  marginal y 9.3566e+53
# 	acceptance rate = 0.0700  for subject 5
# 	phi scelti: (7.914e-02 , 3.358e-03)  marginal y 2.3698e+75
# 	acceptance rate = 0.7200  for subject 6
# 	phi scelti: (1.440e-01 , 6.699e-04)  marginal y 1.8544e+56
#  final_simplex: (array([[1.18719319e-01, 1.29358221e-03, 2.33119782e-02, 1.80125419e-03,
#         9.99999993e-01, 1.70699787e-04],
#        [1.18748842e-01, 1.29298843e-03, 2.33239200e-02, 1.80100182e-03,
#         9.99999988e-01, 1.70703690e-04],
#        [1.18674454e-01, 1.29464578e-03, 2.33048760e-02, 1.80173340e-03,
#         9.99999971e-01, 1.70650251e-04],
#        [1.18716640e-01, 1.29421785e-03, 2.33032959e-02, 1.80200582e-03,
#         9.99999978e-01, 1.70636667e-04],
#        [1.18620279e-01, 1.29520023e-03, 2.32831415e-02, 1.80158115e-03,
#         9.99999968e-01, 1.70714407e-04],
#        [1.18741835e-01, 1.29354310e-03, 2.33052592e-02, 1.80166418e-03,
#         9.99999969e-01, 1.70678902e-04],
#        [1.18712942e-01, 1.29487544e-03, 2.32275266e-02, 1.80330658e-03,
#         9.99999974e-01, 1.70706112e-04]]), array([3030.73865636, 3030.73868853, 3030.73869226, 3030.7386937 ,
#        3030.73870542, 3030.73871053, 3030.73871388]))
#            fun: 3030.7386563586706
#        message: 'Optimization terminated successfully.'
#           nfev: 643
#            nit: 391
#         status: 0
#        success: True
#              x: array([1.18719319e-01, 1.29358221e-03, 2.33119782e-02, 1.80125419e-03,
#        9.99999993e-01, 1.70699787e-04])
# ### ottimizazione iterazione :  11
# 	acceptance rate = 0.1700  for subject 1
# 	phi scelti: (1.267e-01 , 7.755e-04)  marginal y 1.3417e+67
# 	acceptance rate = 0.2800  for subject 2
# 	phi scelti: (1.489e-01 , 3.330e-04)  marginal y 7.2010e+58
# 	acceptance rate = 0.8700  for subject 3
# 	phi scelti: (1.240e-01 , 2.307e-04)  marginal y 2.1604e+74
# 	acceptance rate = 0.5300  for subject 4
# 	phi scelti: (1.524e-01 , 2.859e-04)  marginal y 4.2013e+53
# 	acceptance rate = 0.0700  for subject 5
# 	phi scelti: (8.438e-02 , 3.692e-03)  marginal y 3.2759e+75
# 	acceptance rate = 0.8400  for subject 6
# 	phi scelti: (1.353e-01 , 5.508e-04)  marginal y 8.9972e+55
#  final_simplex: (array([[1.28608395e-01, 9.77994939e-04, 2.23735983e-02, 1.22784461e-03,
#         9.95176394e-01, 2.23511915e-04],
#        [1.28605339e-01, 9.77954421e-04, 2.23730335e-02, 1.22779344e-03,
#         9.95203470e-01, 2.23518958e-04],
#        [1.28608545e-01, 9.78064825e-04, 2.23745468e-02, 1.22787522e-03,
#         9.95102813e-01, 2.23514329e-04],
#        [1.28605489e-01, 9.78172900e-04, 2.23733684e-02, 1.22785828e-03,
#         9.95181655e-01, 2.23518354e-04],
#        [1.28604967e-01, 9.78144404e-04, 2.23747457e-02, 1.22775433e-03,
#         9.95176634e-01, 2.23511853e-04],
#        [1.28610145e-01, 9.78192673e-04, 2.23721862e-02, 1.22777354e-03,
#         9.95158737e-01, 2.23512958e-04],
#        [1.28605080e-01, 9.78014840e-04, 2.23692939e-02, 1.22778709e-03,
#         9.95261622e-01, 2.23516054e-04]]), array([3497.77594199, 3497.77594199, 3497.77594201, 3497.77594204,
#        3497.77594206, 3497.77594206, 3497.77594213]))
#            fun: 3497.775941985699
#        message: 'Optimization terminated successfully.'
#           nfev: 307
#            nit: 186
#         status: 0
#        success: True
#              x: array([1.28608395e-01, 9.77994939e-04, 2.23735983e-02, 1.22784461e-03,
#        9.95176394e-01, 2.23511915e-04])
# ### ottimizazione iterazione :  12
# 	acceptance rate = 0.4600  for subject 1
# 	phi scelti: (1.741e-01 , 4.736e-04)  marginal y 2.8598e+66
# 	acceptance rate = 0.7500  for subject 2
# 	phi scelti: (1.119e-01 , 3.532e-04)  marginal y 8.3698e+57
# 	acceptance rate = 0.8200  for subject 3
# 	phi scelti: (1.801e-01 , 2.104e-05)  marginal y 1.5294e+73
# 	acceptance rate = 0.7300  for subject 4
# 	phi scelti: (1.345e-01 , 2.975e-04)  marginal y 4.0196e+53
# 	acceptance rate = 0.1400  for subject 5
# 	phi scelti: (9.173e-02 , 2.302e-03)  marginal y 3.8721e+75
# 	acceptance rate = 0.8200  for subject 6
# 	phi scelti: (1.349e-01 , 7.839e-04)  marginal y 1.1404e+55
#  final_simplex: (array([[0.13786809, 0.00070517, 0.03141212, 0.00074904, 0.29204338,
#         0.00033155],
#        [0.13787233, 0.00070519, 0.03141235, 0.00074902, 0.29210243,
#         0.00033155],
#        [0.13786941, 0.00070516, 0.03141275, 0.00074906, 0.29205537,
#         0.00033156],
#        [0.13786993, 0.0007052 , 0.03141258, 0.00074898, 0.29204341,
#         0.00033155],
#        [0.13786956, 0.00070513, 0.03141485, 0.000749  , 0.29199641,
#         0.00033155],
#        [0.13787322, 0.00070515, 0.03141392, 0.00074903, 0.29202211,
#         0.00033155],
#        [0.137873  , 0.00070506, 0.03141337, 0.00074896, 0.29202715,
#         0.00033156]]), array([3530.75654963, 3530.75654964, 3530.75654965, 3530.75654966,
#        3530.75654966, 3530.75654967, 3530.75654972]))
#            fun: 3530.756549634849
#        message: 'Optimization terminated successfully.'
#           nfev: 281
#            nit: 173
#         status: 0
#        success: True
#              x: array([0.13786809, 0.00070517, 0.03141212, 0.00074904, 0.29204338,
#        0.00033155])
# ### ottimizazione iterazione :  13
# 	acceptance rate = 0.7900  for subject 1
# 	phi scelti: (2.188e-01 , 5.720e-04)  marginal y 4.7845e+66
# 	acceptance rate = 0.9100  for subject 2
# 	phi scelti: (1.192e-01 , 3.472e-04)  marginal y 1.0157e+57
# 	acceptance rate = 0.8500  for subject 3
# 	phi scelti: (1.728e-01 , 2.726e-05)  marginal y 1.2977e+71
# 	acceptance rate = 0.8100  for subject 4
# 	phi scelti: (1.472e-01 , 4.190e-04)  marginal y 1.2434e+53
# 	acceptance rate = 0.6700  for subject 5
# 	phi scelti: (1.754e-01 , 1.029e-03)  marginal y 5.0468e+79
# 	acceptance rate = 0.8900  for subject 6
# 	phi scelti: (1.539e-01 , 7.888e-04)  marginal y 4.1328e+53
#  final_simplex: (array([[1.67327362e-01, 6.87394888e-04, 3.17490860e-02, 4.28487545e-04,
#         9.99999812e-01, 1.45703137e-04],
#        [1.67276368e-01, 6.87001285e-04, 3.17493290e-02, 4.29145771e-04,
#         9.99999702e-01, 1.45744452e-04],
#        [1.67366421e-01, 6.86793265e-04, 3.17740503e-02, 4.28956298e-04,
#         9.99999372e-01, 1.45791920e-04],
#        [1.67360390e-01, 6.86512082e-04, 3.17785835e-02, 4.29310567e-04,
#         9.99999713e-01, 1.45780992e-04],
#        [1.67295962e-01, 6.87490858e-04, 3.17495216e-02, 4.28513475e-04,
#         9.99999872e-01, 1.45645159e-04],
#        [1.67359940e-01, 6.86742711e-04, 3.17861615e-02, 4.29027178e-04,
#         9.99999621e-01, 1.45743471e-04],
#        [1.67289647e-01, 6.87389201e-04, 3.17496542e-02, 4.28638779e-04,
#         9.99999339e-01, 1.45704773e-04]]), array([-1384.1094873 , -1384.1094437 , -1384.10942809, -1384.10942542,
#        -1384.10942373, -1384.10941984, -1384.10941109]))
#            fun: -1384.109487297284
#        message: 'Optimization terminated successfully.'
#           nfev: 553
#            nit: 346
#         status: 0
#        success: True
#              x: array([1.67327362e-01, 6.87394888e-04, 3.17490860e-02, 4.28487545e-04,
#        9.99999812e-01, 1.45703137e-04])
# ### ottimizazione iterazione :  14
# 	acceptance rate = 0.2300  for subject 1
# 	phi scelti: (1.309e-01 , 2.896e-04)  marginal y 3.1446e+67
# 	acceptance rate = 0.2200  for subject 2
# 	phi scelti: (1.390e-01 , 2.474e-04)  marginal y 1.0446e+59
# 	acceptance rate = 0.8400  for subject 3
# 	phi scelti: (1.671e-01 , 7.136e-06)  marginal y 2.7249e+74
# 	acceptance rate = 0.3300  for subject 4
# 	phi scelti: (1.533e-01 , 4.326e-04)  marginal y 8.1929e+53
# 	acceptance rate = 0.0600  for subject 5
# 	phi scelti: (1.405e-01 , 1.052e-03)  marginal y 1.2253e+76
# 	acceptance rate = 0.8000  for subject 6
# 	phi scelti: (1.547e-01 , 1.090e-03)  marginal y 2.5689e+56
#  final_simplex: (array([[1.47830774e-01, 8.80634901e-04, 1.54411262e-02, 8.38827738e-04,
#         9.99999876e-01, 2.31052982e-04],
#        [1.47807831e-01, 8.79933744e-04, 1.54853391e-02, 8.37670519e-04,
#         9.99999802e-01, 2.31134311e-04],
#        [1.47821425e-01, 8.80982557e-04, 1.54172775e-02, 8.39439238e-04,
#         9.99999236e-01, 2.31089256e-04],
#        [1.47910446e-01, 8.81142625e-04, 1.54052782e-02, 8.39604519e-04,
#         9.99999420e-01, 2.31095366e-04],
#        [1.47860426e-01, 8.79686038e-04, 1.55026631e-02, 8.37113638e-04,
#         9.99998591e-01, 2.31140343e-04],
#        [1.47891590e-01, 8.81137751e-04, 1.54056426e-02, 8.39611715e-04,
#         9.99998996e-01, 2.31112455e-04],
#        [1.47859031e-01, 8.81291899e-04, 1.53931981e-02, 8.39988689e-04,
#         9.99999130e-01, 2.31145945e-04]]), array([2741.06557481, 2741.06559508, 2741.06564918, 2741.06565454,
#        2741.06566644, 2741.06566894, 2741.06567432]))
#            fun: 2741.0655748136946
#        message: 'Optimization terminated successfully.'
#           nfev: 442
#            nit: 274
#         status: 0
#        success: True
#              x: array([1.47830774e-01, 8.80634901e-04, 1.54411262e-02, 8.38827738e-04,
#        9.99999876e-01, 2.31052982e-04])
# ### ottimizazione iterazione :  15
# 	acceptance rate = 0.3100  for subject 1
# 	phi scelti: (1.530e-01 , 2.092e-04)  marginal y 3.2249e+66
# 	acceptance rate = 0.5500  for subject 2
# 	phi scelti: (1.777e-01 , 2.747e-04)  marginal y 2.1565e+58
# 	acceptance rate = 0.7000  for subject 3
# 	phi scelti: (1.506e-01 , 9.476e-06)  marginal y 8.7822e+72
# 	acceptance rate = 0.6100  for subject 4
# 	phi scelti: (1.832e-01 , 3.817e-04)  marginal y 6.9217e+53
# 	acceptance rate = 0.0700  for subject 5
# 	phi scelti: (1.280e-01 , 1.149e-03)  marginal y 5.0426e+75
# 	acceptance rate = 0.6300  for subject 6
# 	phi scelti: (1.666e-01 , 5.848e-04)  marginal y 8.3620e+54
#  final_simplex: (array([[1.60126418e-01, 4.55640971e-04, 1.98957035e-02, 3.76810450e-04,
#         1.32064275e-04, 1.53935034e-04],
#        [1.60128553e-01, 4.55961320e-04, 1.98854878e-02, 3.76634253e-04,
#         1.67255419e-04, 1.53979284e-04],
#        [1.60118479e-01, 4.55418972e-04, 1.99044549e-02, 3.76730625e-04,
#         1.98888585e-04, 1.53935325e-04],
#        [1.60099964e-01, 4.55842482e-04, 1.98792743e-02, 3.77071188e-04,
#         1.51165879e-04, 1.53980924e-04],
#        [1.60131629e-01, 4.55281286e-04, 1.99120207e-02, 3.76437756e-04,
#         1.73129076e-04, 1.53943457e-04],
#        [1.60162115e-01, 4.55149963e-04, 1.99060242e-02, 3.76769138e-04,
#         1.64014120e-04, 1.53927435e-04],
#        [1.60110494e-01, 4.55828748e-04, 1.98909840e-02, 3.76697290e-04,
#         2.05906196e-04, 1.53969837e-04]]), array([3456.71116535, 3456.71121066, 3456.71121236, 3456.71121486,
#        3456.71121587, 3456.71121595, 3456.71123025]))
#            fun: 3456.7111653451598
#        message: 'Optimization terminated successfully.'
#           nfev: 396
#            nit: 249
#         status: 0
#        success: True
#              x: array([1.60126418e-01, 4.55640971e-04, 1.98957035e-02, 3.76810450e-04,
#        1.32064275e-04, 1.53935034e-04])
# ### ottimizazione iterazione :  16
# 	acceptance rate = 0.6000  for subject 1
# 	phi scelti: (1.761e-01 , 1.071e-03)  marginal y 9.9651e+71
# 	acceptance rate = 0.7200  for subject 2
# 	phi scelti: (1.963e-01 , 7.450e-04)  marginal y 3.8105e+61
# 	acceptance rate = 0.8300  for subject 3
# 	phi scelti: (1.684e-01 , 2.614e-05)  marginal y 3.2806e+74
# 	acceptance rate = 0.5900  for subject 4
# 	phi scelti: (2.042e-01 , 7.007e-04)  marginal y 4.4696e+57
# 	acceptance rate = 0.4500  for subject 5
# 	phi scelti: (1.727e-01 , 1.232e-03)  marginal y 1.7123e+86
# 	acceptance rate = 0.7000  for subject 6
# 	phi scelti: (1.722e-01 , 7.341e-04)  marginal y 3.8233e+57
#  final_simplex: (array([[1.81647676e-01, 7.51763093e-04, 1.35270356e-02, 3.79252936e-04,
#         2.52091904e-04, 7.32602119e-05],
#        [1.81651281e-01, 7.51760728e-04, 1.35751611e-02, 3.79293289e-04,
#         2.51947156e-04, 7.32256436e-05],
#        [1.81718377e-01, 7.51860662e-04, 1.35422981e-02, 3.78733400e-04,
#         2.51985646e-04, 7.32535764e-05],
#        [1.81690288e-01, 7.52788414e-04, 1.35614784e-02, 3.79213459e-04,
#         2.52123906e-04, 7.32259309e-05],
#        [1.81634831e-01, 7.52271674e-04, 1.35348710e-02, 3.78875440e-04,
#         2.52001910e-04, 7.33227741e-05],
#        [1.81658141e-01, 7.52621995e-04, 1.35167362e-02, 3.77801065e-04,
#         2.52001988e-04, 7.32640069e-05],
#        [1.81656068e-01, 7.53302206e-04, 1.35378727e-02, 3.79497181e-04,
#         2.51848344e-04, 7.32595947e-05]]), array([-2130.77787609, -2130.77783102, -2130.77781256, -2130.77779198,
#        -2130.77779126, -2130.77778443, -2130.77777678]))
#            fun: -2130.777876085493
#        message: 'Optimization terminated successfully.'
#           nfev: 443
#            nit: 288
#         status: 0
#        success: True
#              x: array([1.81647676e-01, 7.51763093e-04, 1.35270356e-02, 3.79252936e-04,
#        2.52091904e-04, 7.32602119e-05])
# ### ottimizazione iterazione :  17
# 	acceptance rate = 0.3000  for subject 1
# 	phi scelti: (1.708e-01 , 1.131e-03)  marginal y 1.8210e+76
# 	acceptance rate = 0.3800  for subject 2
# 	phi scelti: (1.811e-01 , 1.502e-03)  marginal y 2.6668e+66
# 	acceptance rate = 0.5800  for subject 3
# 	phi scelti: (1.948e-01 , 2.906e-05)  marginal y 5.1365e+71
# 	acceptance rate = 0.3700  for subject 4
# 	phi scelti: (2.181e-01 , 6.706e-04)  marginal y 2.5739e+61
# 	acceptance rate = 0.1900  for subject 5
# 	phi scelti: (1.727e-01 , 1.232e-03)  marginal y 5.7946e+90
# 	acceptance rate = 0.4600  for subject 6
# 	phi scelti: (2.118e-01 , 5.289e-04)  marginal y 2.5270e+61
#  final_simplex: (array([[1.91607615e-01, 8.49302568e-04, 1.83778346e-02, 4.92423172e-04,
#         5.51529815e-04, 6.23632847e-05],
#        [1.91629094e-01, 8.48737266e-04, 1.83759897e-02, 4.93109074e-04,
#         5.51657404e-04, 6.24454370e-05],
#        [1.91585694e-01, 8.47262320e-04, 1.83974026e-02, 4.91970425e-04,
#         5.51509782e-04, 6.23833161e-05],
#        [1.91552533e-01, 8.48467527e-04, 1.84327010e-02, 4.94879439e-04,
#         5.51533207e-04, 6.24084654e-05],
#        [1.91564665e-01, 8.48880369e-04, 1.84492812e-02, 4.92976750e-04,
#         5.51855490e-04, 6.23990611e-05],
#        [1.91578790e-01, 8.48972648e-04, 1.83558336e-02, 4.93012466e-04,
#         5.52039231e-04, 6.23482340e-05],
#        [1.91646042e-01, 8.47249407e-04, 1.84034170e-02, 4.92721024e-04,
#         5.51668427e-04, 6.23706536e-05]]), array([-2066.9267165 , -2066.92670913, -2066.92669482, -2066.92665904,
#        -2066.92665571, -2066.92663415, -2066.92663415]))
#            fun: -2066.9267165014285
#        message: 'Optimization terminated successfully.'
#           nfev: 330
#            nit: 211
#         status: 0
#        success: True
#              x: array([1.91607615e-01, 8.49302568e-04, 1.83778346e-02, 4.92423172e-04,
#        5.51529815e-04, 6.23632847e-05])
# ### ottimizazione iterazione :  18
# 	acceptance rate = 0.3100  for subject 1
# 	phi scelti: (1.640e-01 , 1.306e-03)  marginal y 1.0619e+77
# 	acceptance rate = 0.3500  for subject 2
# 	phi scelti: (1.774e-01 , 1.617e-03)  marginal y 1.8830e+67
# 	acceptance rate = 0.6100  for subject 3
# 	phi scelti: (2.391e-01 , 6.741e-05)  marginal y 1.5233e+73
# 	acceptance rate = 0.3700  for subject 4
# 	phi scelti: (2.295e-01 , 6.147e-04)  marginal y 1.5826e+62
# 	acceptance rate = 0.1800  for subject 5
# 	phi scelti: (1.759e-01 , 1.194e-03)  marginal y 2.6855e+91
# 	acceptance rate = 0.4700  for subject 6
# 	phi scelti: (2.437e-01 , 3.990e-04)  marginal y 2.0370e+62
#  final_simplex: (array([[2.04941250e-01, 8.67268152e-04, 3.29718556e-02, 5.44813343e-04,
#         1.11667308e-03, 5.42253292e-05],
#        [2.04901560e-01, 8.64212426e-04, 3.30563461e-02, 5.44941496e-04,
#         1.11623815e-03, 5.42138834e-05],
#        [2.04933328e-01, 8.67103526e-04, 3.29982114e-02, 5.45365682e-04,
#         1.11584230e-03, 5.42130773e-05],
#        [2.04946740e-01, 8.66733862e-04, 3.29675230e-02, 5.45336428e-04,
#         1.11610093e-03, 5.41901100e-05],
#        [2.04946103e-01, 8.64652971e-04, 3.29765418e-02, 5.45339781e-04,
#         1.11610349e-03, 5.42298477e-05],
#        [2.04880960e-01, 8.65765830e-04, 3.29487803e-02, 5.44856540e-04,
#         1.11614277e-03, 5.42078635e-05],
#        [2.04981782e-01, 8.66291117e-04, 3.29639668e-02, 5.44073068e-04,
#         1.11601572e-03, 5.42029415e-05]]), array([-2002.5924271 , -2002.59240491, -2002.59240403, -2002.59238941,
#        -2002.5923852 , -2002.5923819 , -2002.5923597 ]))
#            fun: -2002.5924271030312
#        message: 'Optimization terminated successfully.'
#           nfev: 260
#            nit: 161
#         status: 0
#        success: True
#              x: array([2.04941250e-01, 8.67268152e-04, 3.29718556e-02, 5.44813343e-04,
#        1.11667308e-03, 5.42253292e-05])
# ### ottimizazione iterazione :  19
# 	acceptance rate = 0.2300  for subject 1
# 	phi scelti: (1.640e-01 , 1.306e-03)  marginal y 4.0058e+77
# 	acceptance rate = 0.2700  for subject 2
# 	phi scelti: (1.774e-01 , 1.617e-03)  marginal y 8.7939e+67
# 	acceptance rate = 0.5300  for subject 3
# 	phi scelti: (2.118e-01 , 3.281e-04)  marginal y 4.6310e+83
# 	acceptance rate = 0.2500  for subject 4
# 	phi scelti: (2.297e-01 , 6.235e-04)  marginal y 7.1952e+62
# 	acceptance rate = 0.1800  for subject 5
# 	phi scelti: (1.759e-01 , 1.194e-03)  marginal y 6.2457e+91
# 	acceptance rate = 0.4800  for subject 6
# 	phi scelti: (2.841e-01 , 3.384e-04)  marginal y 1.2892e+63
#  final_simplex: (array([[2.07146277e-01, 9.00848634e-04, 4.11890444e-02, 4.96832712e-04,
#         2.08046646e-03, 3.01487832e-05],
#        [2.07197260e-01, 9.01176149e-04, 4.11630378e-02, 4.97410240e-04,
#         2.08085661e-03, 3.01565204e-05],
#        [2.07194817e-01, 9.01568429e-04, 4.11553871e-02, 4.97730882e-04,
#         2.08044369e-03, 3.01529326e-05],
#        [2.07115520e-01, 9.01028112e-04, 4.11086596e-02, 4.97431880e-04,
#         2.08079926e-03, 3.01522323e-05],
#        [2.07201586e-01, 9.00646886e-04, 4.11380572e-02, 4.97298049e-04,
#         2.08095233e-03, 3.01509824e-05],
#        [2.07088752e-01, 9.01437420e-04, 4.11796108e-02, 4.97794917e-04,
#         2.08130128e-03, 3.01547572e-05],
#        [2.07131858e-01, 8.99889813e-04, 4.11894700e-02, 4.97433780e-04,
#         2.08059664e-03, 3.01519895e-05]]), array([-1985.60914025, -1985.60914   , -1985.6091376 , -1985.60913209,
#        -1985.60913123, -1985.60912902, -1985.609129  ]))
#            fun: -1985.6091402490965
#        message: 'Optimization terminated successfully.'
#           nfev: 307
#            nit: 193
#         status: 0
#        success: True
#              x: array([2.07146277e-01, 9.00848634e-04, 4.11890444e-02, 4.96832712e-04,
#        2.08046646e-03, 3.01487832e-05])
# ### ottimizazione iterazione :  20
# 	acceptance rate = 0.1100  for subject 1
# 	phi scelti: (1.650e-01 , 1.266e-03)  marginal y 3.4785e+78
# 	acceptance rate = 0.1400  for subject 2
# 	phi scelti: (1.731e-01 , 1.741e-03)  marginal y 2.0101e+70
# 	acceptance rate = 0.2800  for subject 3
# 	phi scelti: (1.884e-01 , 3.800e-04)  marginal y 5.9708e+86
# 	acceptance rate = 0.2100  for subject 4
# 	phi scelti: (2.297e-01 , 6.235e-04)  marginal y 1.6238e+65
# 	acceptance rate = 0.1300  for subject 5
# 	phi scelti: (1.759e-01 , 1.194e-03)  marginal y 5.8286e+89
# 	acceptance rate = 0.4300  for subject 6
# 	phi scelti: (2.959e-01 , 3.177e-04)  marginal y 1.0622e+66
#  final_simplex: (array([[2.04675976e-01, 9.20460649e-04, 4.58718887e-02, 5.17908230e-04,
#         4.45575312e-03, 2.96163755e-05],
#        [2.04628477e-01, 9.19546623e-04, 4.58499970e-02, 5.17813015e-04,
#         4.45478292e-03, 2.96146477e-05],
#        [2.04741617e-01, 9.19883855e-04, 4.59048098e-02, 5.17916826e-04,
#         4.45473601e-03, 2.96119788e-05],
#        [2.04665036e-01, 9.19317768e-04, 4.58147323e-02, 5.17580172e-04,
#         4.45492983e-03, 2.96096148e-05],
#        [2.04674486e-01, 9.19995868e-04, 4.59024856e-02, 5.18564616e-04,
#         4.45669450e-03, 2.96030585e-05],
#        [2.04746266e-01, 9.20762232e-04, 4.59114582e-02, 5.18527710e-04,
#         4.45598926e-03, 2.95948315e-05],
#        [2.04703391e-01, 9.20438199e-04, 4.58536723e-02, 5.19172675e-04,
#         4.45690909e-03, 2.96149372e-05]]), array([-1927.28658836, -1927.28658446, -1927.28658151, -1927.28657721,
#        -1927.28657467, -1927.28656036, -1927.28655723]))
#            fun: -1927.2865883601087
#        message: 'Optimization terminated successfully.'
#           nfev: 315
#            nit: 202
#         status: 0
#        success: True
#              x: array([2.04675976e-01, 9.20460649e-04, 4.58718887e-02, 5.17908230e-04,
#        4.45575312e-03, 2.96163755e-05])
# ### ottimizazione iterazione :  21
# 	acceptance rate = 0.1500  for subject 1
# 	phi scelti: (1.638e-01 , 1.260e-03)  marginal y 3.7296e+78
# 	acceptance rate = 0.1800  for subject 2
# 	phi scelti: (1.716e-01 , 1.895e-03)  marginal y 2.6594e+70
# 	acceptance rate = 0.4300  for subject 3
# 	phi scelti: (1.884e-01 , 3.800e-04)  marginal y 6.8082e+86
# 	acceptance rate = 0.1600  for subject 4
# 	phi scelti: (2.297e-01 , 6.235e-04)  marginal y 1.8363e+65
# 	acceptance rate = 0.0500  for subject 5
# 	phi scelti: (1.796e-01 , 1.146e-03)  marginal y 4.5983e+89
# 	acceptance rate = 0.4300  for subject 6
# 	phi scelti: (2.862e-01 , 3.293e-04)  marginal y 1.3472e+66
#  final_simplex: (array([[2.03241629e-01, 9.38913914e-04, 4.26636002e-02, 5.54473174e-04,
#         8.93047715e-03, 2.95471860e-05],
#        [2.03188099e-01, 9.39504810e-04, 4.26038111e-02, 5.54186869e-04,
#         8.93093390e-03, 2.95527510e-05],
#        [2.03208219e-01, 9.38301008e-04, 4.26015279e-02, 5.53938413e-04,
#         8.92740801e-03, 2.95584654e-05],
#        [2.03171055e-01, 9.38012159e-04, 4.25651175e-02, 5.54250441e-04,
#         8.92718596e-03, 2.95435924e-05],
#        [2.03176376e-01, 9.39236929e-04, 4.26218580e-02, 5.53133519e-04,
#         8.92580071e-03, 2.95485641e-05],
#        [2.03284960e-01, 9.38515012e-04, 4.25760268e-02, 5.53617299e-04,
#         8.93137368e-03, 2.95545259e-05],
#        [2.03280722e-01, 9.38526139e-04, 4.25840426e-02, 5.55051405e-04,
#         8.92523231e-03, 2.95477223e-05]]), array([-1871.94960347, -1871.94959094, -1871.9495849 , -1871.94957372,
#        -1871.94957199, -1871.94956873, -1871.94956537]))
#            fun: -1871.9496034676613
#        message: 'Optimization terminated successfully.'
#           nfev: 344
#            nit: 227
#         status: 0
#        success: True
#              x: array([2.03241629e-01, 9.38913914e-04, 4.26636002e-02, 5.54473174e-04,
#        8.93047715e-03, 2.95471860e-05])
# ### ottimizazione iterazione :  22
# 	acceptance rate = 0.1100  for subject 1
# 	phi scelti: (1.638e-01 , 1.260e-03)  marginal y 5.7145e+78
# 	acceptance rate = 0.1500  for subject 2
# 	phi scelti: (1.703e-01 , 1.846e-03)  marginal y 2.8507e+70
# 	acceptance rate = 0.3300  for subject 3
# 	phi scelti: (1.884e-01 , 3.800e-04)  marginal y 7.4895e+86
# 	acceptance rate = 0.2000  for subject 4
# 	phi scelti: (2.297e-01 , 6.235e-04)  marginal y 1.8562e+65
# 	acceptance rate = 0.0900  for subject 5
# 	phi scelti: (1.765e-01 , 1.188e-03)  marginal y 1.0760e+90
# 	acceptance rate = 0.3400  for subject 6
# 	phi scelti: (2.862e-01 , 3.293e-04)  marginal y 1.3524e+66
#  final_simplex: (array([[2.02479510e-01, 9.37985051e-04, 4.30612148e-02, 5.43332849e-04,
#         1.57881306e-02, 3.02780507e-05],
#        [2.02574478e-01, 9.37634837e-04, 4.30879357e-02, 5.43309703e-04,
#         1.57855202e-02, 3.02854949e-05],
#        [2.02523766e-01, 9.38188886e-04, 4.30990934e-02, 5.42530837e-04,
#         1.57858182e-02, 3.02798407e-05],
#        [2.02465866e-01, 9.36936875e-04, 4.31591170e-02, 5.42957408e-04,
#         1.57870919e-02, 3.02790202e-05],
#        [2.02514420e-01, 9.38480555e-04, 4.30449973e-02, 5.42929496e-04,
#         1.57790668e-02, 3.02806587e-05],
#        [2.02456717e-01, 9.37613776e-04, 4.30664347e-02, 5.43151513e-04,
#         1.57881508e-02, 3.02972501e-05],
#        [2.02541475e-01, 9.36756997e-04, 4.30628663e-02, 5.42526318e-04,
#         1.57809277e-02, 3.02796313e-05]]), array([-1825.09157923, -1825.09157572, -1825.09157116, -1825.0915663 ,
#        -1825.09155748, -1825.09155512, -1825.09154791]))
#            fun: -1825.091579226134
#        message: 'Optimization terminated successfully.'
#           nfev: 319
#            nit: 202
#         status: 0
#        success: True
#              x: array([2.02479510e-01, 9.37985051e-04, 4.30612148e-02, 5.43332849e-04,
#        1.57881306e-02, 3.02780507e-05])
# ### ottimizazione iterazione :  23
# 	acceptance rate = 0.1800  for subject 1
# 	phi scelti: (1.727e-01 , 1.092e-03)  marginal y 9.5962e+78
# 	acceptance rate = 0.1900  for subject 2
# 	phi scelti: (1.591e-01 , 2.353e-03)  marginal y 4.0275e+70
# 	acceptance rate = 0.4400  for subject 3
# 	phi scelti: (1.884e-01 , 3.800e-04)  marginal y 5.9822e+86
# 	acceptance rate = 0.1700  for subject 4
# 	phi scelti: (2.297e-01 , 6.235e-04)  marginal y 1.5045e+65
# 	acceptance rate = 0.1000  for subject 5
# 	phi scelti: (1.833e-01 , 1.111e-03)  marginal y 6.8749e+90
# 	acceptance rate = 0.4000  for subject 6
# 	phi scelti: (2.852e-01 , 3.255e-04)  marginal y 9.9917e+65
#  final_simplex: (array([[2.02998499e-01, 9.80720643e-04, 4.26362106e-02, 6.85705370e-04,
#         2.85809504e-02, 2.83832615e-05],
#        [2.03097089e-01, 9.81704939e-04, 4.26659581e-02, 6.86682858e-04,
#         2.85833487e-02, 2.83765552e-05],
#        [2.03064392e-01, 9.81525142e-04, 4.25842875e-02, 6.85257510e-04,
#         2.85588799e-02, 2.83887997e-05],
#        [2.03032140e-01, 9.79717460e-04, 4.27272923e-02, 6.86500712e-04,
#         2.85602702e-02, 2.83801589e-05],
#        [2.02915665e-01, 9.81647465e-04, 4.26699748e-02, 6.87285389e-04,
#         2.85685160e-02, 2.83850530e-05],
#        [2.03025366e-01, 9.82448490e-04, 4.27244595e-02, 6.85256169e-04,
#         2.85687106e-02, 2.83746801e-05],
#        [2.02931774e-01, 9.79870689e-04, 4.26608611e-02, 6.86948050e-04,
#         2.85675828e-02, 2.83663381e-05]]), array([-1781.61415162, -1781.61414637, -1781.61413504, -1781.61413471,
#        -1781.61413146, -1781.61408784, -1781.61408462]))
#            fun: -1781.6141516236016
#        message: 'Optimization terminated successfully.'
#           nfev: 384
#            nit: 249
#         status: 0
#        success: True
#              x: array([2.02998499e-01, 9.80720643e-04, 4.26362106e-02, 6.85705370e-04,
#        2.85809504e-02, 2.83832615e-05])
# ### ottimizazione iterazione :  24
# 	acceptance rate = 0.1700  for subject 1
# 	phi scelti: (1.727e-01 , 1.092e-03)  marginal y 6.3990e+79
# 	acceptance rate = 0.2100  for subject 2
# 	phi scelti: (1.591e-01 , 2.353e-03)  marginal y 4.8580e+70
# 	acceptance rate = 0.3600  for subject 3
# 	phi scelti: (1.853e-01 , 3.766e-04)  marginal y 1.1584e+87
# 	acceptance rate = 0.2500  for subject 4
# 	phi scelti: (2.297e-01 , 6.235e-04)  marginal y 2.1054e+65
# 	acceptance rate = 0.0500  for subject 5
# 	phi scelti: (1.971e-01 , 1.003e-03)  marginal y 1.0808e+92
# 	acceptance rate = 0.3000  for subject 6
# 	phi scelti: (2.852e-01 , 3.255e-04)  marginal y 1.7085e+66
#  final_simplex: (array([[2.04856626e-01, 9.64386864e-04, 4.20717615e-02, 6.86061067e-04,
#         5.90510029e-02, 2.79268523e-05],
#        [2.04764178e-01, 9.62217101e-04, 4.20553473e-02, 6.86973797e-04,
#         5.90442482e-02, 2.79229276e-05],
#        [2.04865355e-01, 9.64196300e-04, 4.21456742e-02, 6.86894656e-04,
#         5.90596917e-02, 2.79270696e-05],
#        [2.04891004e-01, 9.63577938e-04, 4.20672657e-02, 6.86984948e-04,
#         5.90662277e-02, 2.79314524e-05],
#        [2.04788205e-01, 9.64620144e-04, 4.20511280e-02, 6.86463189e-04,
#         5.90448725e-02, 2.79314717e-05],
#        [2.04814715e-01, 9.64029124e-04, 4.20153333e-02, 6.86805970e-04,
#         5.90471863e-02, 2.79226664e-05],
#        [2.04787284e-01, 9.64146286e-04, 4.19906117e-02, 6.86012786e-04,
#         5.90621688e-02, 2.79253012e-05]]), array([-1723.98845309, -1723.98842772, -1723.98842193, -1723.98842158,
#        -1723.98841424, -1723.9884086 , -1723.98840792]))
#            fun: -1723.9884530863167
#        message: 'Optimization terminated successfully.'
#           nfev: 306
#            nit: 196
#         status: 0
#        success: True
#              x: array([2.04856626e-01, 9.64386864e-04, 4.20717615e-02, 6.86061067e-04,
#        5.90510029e-02, 2.79268523e-05])
# ### ottimizazione iterazione :  25
# 	acceptance rate = 0.1900  for subject 1
# 	phi scelti: (1.686e-01 , 1.219e-03)  marginal y 2.9513e+80
# 	acceptance rate = 0.2600  for subject 2
# 	phi scelti: (1.708e-01 , 1.787e-03)  marginal y 1.5857e+70
# 	acceptance rate = 0.4200  for subject 3
# 	phi scelti: (1.953e-01 , 3.749e-04)  marginal y 1.3314e+87
# 	acceptance rate = 0.2700  for subject 4
# 	phi scelti: (2.414e-01 , 5.806e-04)  marginal y 1.0733e+65
# 	acceptance rate = 0.1900  for subject 5
# 	phi scelti: (1.971e-01 , 1.003e-03)  marginal y 1.5944e+93
# 	acceptance rate = 0.4100  for subject 6
# 	phi scelti: (2.852e-01 , 3.255e-04)  marginal y 1.3128e+66
#  final_simplex: (array([[2.09756891e-01, 8.81803727e-04, 4.13934418e-02, 5.16896019e-04,
#         1.09219876e-01, 3.69266162e-05],
#        [2.09822831e-01, 8.81683710e-04, 4.13600034e-02, 5.16766846e-04,
#         1.09197845e-01, 3.69125595e-05],
#        [2.09730268e-01, 8.81737478e-04, 4.13398322e-02, 5.17780102e-04,
#         1.09239616e-01, 3.69068054e-05],
#        [2.09762184e-01, 8.81415227e-04, 4.13478867e-02, 5.17440428e-04,
#         1.09223034e-01, 3.69375685e-05],
#        [2.09679546e-01, 8.82512848e-04, 4.13107255e-02, 5.16991781e-04,
#         1.09183168e-01, 3.69100544e-05],
#        [2.09748325e-01, 8.81040668e-04, 4.12962918e-02, 5.16460915e-04,
#         1.09245111e-01, 3.69217026e-05],
#        [2.09682736e-01, 8.81080707e-04, 4.13481124e-02, 5.16787147e-04,
#         1.09177293e-01, 3.69013094e-05]]), array([-1649.77152524, -1649.77151637, -1649.77151233, -1649.77150419,
#        -1649.77149935, -1649.77149727, -1649.7714965 ]))
#            fun: -1649.7715252449584
#        message: 'Optimization terminated successfully.'
#           nfev: 265
#            nit: 170
#         status: 0
#        success: True
#              x: array([2.09756891e-01, 8.81803727e-04, 4.13934418e-02, 5.16896019e-04,
#        1.09219876e-01, 3.69266162e-05])
# ### ottimizazione iterazione :  26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-3251b21e47cd> in <module>()
#       4 SAEM = Stochasti_Approximation_Expectation_Maximization()
#       5 #SAEM.inizializza(theta)
# ----> 6 SAEM.run(theta)
#       7 print("tempo esecuzione : %.5f "% (time()-start))
#
# ~\Desktop\data science\tesi\python-script\SAEM.py in run(self, theta_init)
#      32                 if iterazione > 0:
#      33                     self.phi_subject = self.PhiALL[iterazione-1, subject-1, :]
# ---> 34                 phi, X = self.PMCMC.sample_PMCMC(subject, self.theta_choose, self.phi_subject)
#      35                 self.PhiALL[iterazione, subject-1, :] = phi  #self.PMCMC.phi_PMCMC[-1,:] ;
#      36
#
# ~\Desktop\data science\tesi\python-script\particle_markov_chain_monte_carlo.py in sample_PMCMC(self, soggetto, theta, phi_init)
#     158             phi_star = self.proposalPhi_sample(phi)
#     159
# --> 160             self.fit_SMC( soggetto, theta , phi_star)
#     161             X_star = self.sampling_a_path();
#     162             marginal_star = self.marginal_y
#
# ~\Desktop\data science\tesi\python-script\particle_markov_chain_monte_carlo.py in fit_SMC(self, soggetto, theta, phi)
#      40         self.X_tot = np.zeros((self.np, len(self.Y)))
#      41         self.first_step()  # inizializza x(0)
# ---> 42         self.second_step() # completa le x_i per i = 1,...,len(Y)
#      43
#      44     def first_step(self):
#
# ~\Desktop\data science\tesi\python-script\particle_markov_chain_monte_carlo.py in second_step(self)
#      57         self.X_tot[:,0] = X_n_m
#      58         for t in range(1,len(self.Y)):
# ---> 59             X_n = [self.latent_transition_sampler(x_1,t) for x_1 in X_n_m]
#      60             self.X_tot[:,t]= np.array(X_n)
#      61
#
# ~\Desktop\data science\tesi\python-script\particle_markov_chain_monte_carlo.py in <listcomp>(.0)
#      57         self.X_tot[:,0] = X_n_m
#      58         for t in range(1,len(self.Y)):
# ---> 59             X_n = [self.latent_transition_sampler(x_1,t) for x_1 in X_n_m]
#      60             self.X_tot[:,t]= np.array(X_n)
#      61
#
# ~\Desktop\data science\tesi\python-script\particle_markov_chain_monte_carlo.py in latent_transition_sampler(self, x_t, time)
#      98         u_j = self.EulerStep(x_t, t_j_1, t_j, deltatime)
#      99         s_j = self.theta[4] * u_j * np.sqrt(deltatime)
# --> 100         x_t1 = u_j + s_j* np.random.normal()
#     101         if x_t1 < 1e-30:
#     102             x_t1 = 1e-30
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np
def x_fun_espl(t, alpha, kappa, Y_0):
    y = kappa * np.exp( np.log(Y_0/kappa) *  np.exp(- alpha* t))
    return y

# %%
s_= 6
SAEM.select_subj(s_)
plt.plot(SAEM.timei, SAEM.yobsi, "r*")
tempo = np.linspace(0.0, 25, 25000)
x_hat_medio = x_fun_espl(tempo,  SAEM.theta_choose[0], SAEM.theta_choose[1], 1e-7)  
x_hati = x_fun_espl(tempo, SAEM.PhiALL[SAEM.iterazione,s_ - 1, 0], SAEM.PhiALL[SAEM.iterazione,s_ -1, 1], 1e-7)  
plt.plot(tempo, x_hati, "g-", label = "ultimi phii") 
plt.plot(tempo, x_hat_medio, label = "medio popolazione")
plt.legend()
